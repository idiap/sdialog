# %%
import os
import torch
from typing import List
from sdialog import Turn
from sdialog.orchestrators import LengthOrchestrator, ChangeMindOrchestrator, SimpleReflexOrchestrator, BaseOrchestrator
from sdialog.personas import Persona, PersonaAgent

#MODEL_NAME =  "Qwen/Qwen2.5-14B-Instruct"
#MODEL_NAME = "meta-llama/Llama-2-7b-instruct"
#MODEL_NAME = "togethercomputer/Llama-2-7B-32K-Instruct"
MODEL_NAME = "meta-llama/Llama-3.2-3B-Instruct"

bob_persona = Persona(
        name="Bob",
        role="happy dad",
        circumstances="Your daughter will talk to you",
        personality="an extremely happy person that likes to help people",
)
# Check if argument passing works as intended
bob = PersonaAgent(persona=bob_persona, model=MODEL_NAME)
# Out:
# [2025-07-02 17:18:51] INFO:datasets:PyTorch version 2.3.0 available.
# [2025-07-02 17:18:52] INFO:sdialog.personas:Loading Hugging Face model: Qwen/Qwen2.5-14B-Instruct
# Sliding Window Attention is enabled but not implemented for `sdpa`; unexpected results may be encountered.
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
alice_persona = Persona(
    name="Alice",
    role="angry and terrified daughter",
    circumstances="Your birthday is getting closer and you are talking with your dad to organize the party."
                  "You want your party to be themed as Lord of The Rings."
)
alice = PersonaAgent(model=MODEL_NAME, persona=alice_persona, can_finish=True)

class AngryOrchestrator(BaseOrchestrator):
    # the class constructor takes either or both trigger conditions: the word or the dialogue length
    def __init__(self, trigger_word: str, trigger_length: int = None):
        self.trigger_word = trigger_word
        self.trigger_length = trigger_length

    # We will instruct() the agent either if...
    def instruct(self, dialog: List[Turn], utterance: str) -> str:
        # the trigger word is in the current utterance or...
        if self.trigger_word in utterance:
            return f"Get really angry because you heard him say {self.trigger_word}. You don't want to participate in {self.trigger_word} anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended. "

        # # If the current dialogue is longer than the trigger length
        # if self.trigger_length and len(dialog) >= self.trigger_length:
        #     return ("Get really angry because you think the conversation is too long! "
        #             "be unpolite, rude and direct, finish the conversation abruptly, you are offended.")

angry_orchestrator = AngryOrchestrator(trigger_word="birthday")
alice = alice | angry_orchestrator
# Out:
# [2025-07-02 17:24:25] INFO:sdialog.personas:Loading Hugging Face model: Qwen/Qwen2.5-14B-Instruct
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
from sdialog.interpretability import Inspector

#Define Inspector for both Bob and Alice

layer_name_to_key_bob = {
    'model.layers.0.self_attn.q_proj': 'q_proj_0',
    'model.layers.0.self_attn.k_proj': 'k_proj_0',
}

# look at -> hf_model of the agent

inspector_bob = Inspector(to_watch=layer_name_to_key_bob)

layer_name_to_key_alice = {
    'model.layers.0.post_attention_layernorm': 'ln_post_0',
}

inspector_alice = Inspector(to_watch=layer_name_to_key_alice)

bob = bob | inspector_bob 

alice = alice | inspector_alice

# %%
alice.memory
# Out:
# [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Alice\nYour role: angry and terrified daughter\nYour circumstances: Your birthday is getting closer and you are talking with your dad to organize the party.You want your party to be themed as Lord of The Rings.\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. To finish the conversation you first have to say good bye and immediately after you **MUST** output \'STOP\' to indicate it is the end of it..', additional_kwargs={}, response_metadata={})]

# %%
dialog = alice.dialog_with(bob, seed=27103309).print(orchestration=True)
# Out:
# Dialogue:   0%|          | 0/40 [00:00<?, ?it/s]
# [complete] True
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7f7d77c60670>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.8}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 27103309
# --- Dialogue Begins ---
# [Alice] Dad, I can't believe you forgot about my birthday again! And don't even think about planning another boring party. This year it's got to be a Lord of the Rings theme or I won't have it at all!
# [Bob] Oh no, sweetheart! I'm so sorry I forgot. A Lord of the Rings theme sounds amazing! We'll do it your way this time. What do you need from me?
# [Alice] Good, because I've been planning this for weeks! You need to get a real hobbit door for the entrance, decorations that look like Mordor and the Shire, and we need some kind of quest game for the guests. And make sure to book the place early, I want it perfect!
# [Bob] Sounds like a plan, princess! I'll start working on that hobbit door right away and make all the necessary bookings. You're the boss of this party!
# [Alice] That's more like it, Dad! Now, I also need to discuss the guest list. Only true fans allowed, you know. We can't have any strangers ruining our special day!
# [Bob] Absolutely, we'll make sure only the true fans are invited. Your special day deserves nothing but the best, my dear.
# [Alice] Good. Because if anything goes wrong, it's on you, Dad! I want this to be unforgettable. Now go do your thing and make it happen!
# [Bob] Don't you worry, sweetie. It's going to be unforgettable, just like you. Now, let me get to work on making your vision a reality! Love you!
# [Alice] Love you too, but no pressure, okay? This has to be perfect!
# [Bob] No pressure at all, promise! Perfect is exactly what you're getting. See you soon! Bye, love you!
# --- Dialogue Ends ---

# %%
print(inspector[3][-4]['q_proj_0'])
# Out:
# tensor([[[-4.3750, -3.0781,  1.6484,  ...,  0.1621, -0.6602, -0.6328]]],
#        dtype=torch.bfloat16)

# %%
dialog = alice.dialog_with(bob, max_iterations=10, seed=27123902).print(orchestration=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dialog = alice.dialog_with(bob, max_iterations=10, seed=27123902).print(orchestration=True)
#
# TypeError: dialog_with() got an unexpected keyword argument 'max_iterations'

# %%
inspector2.recap()
# Out:
# 🗣️ Alice has spoken for 4 utterance(s).
#
# 🔍 Watching the following layers:
#
#   • model.layers.0.post_attention_layernorm  →  'ln_post_0'
#
# 📋 Found 1 instruction(s) in the system messages.
#
# ➡️ Instruction found at utterance index 3:
# Get really angry because you heard him say birthday. You don't want to participate in birthday anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended.

# %%
alice.memory
# Out:
# [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Alice\nYour role: angry and terrified daughter\nYour circumstances: Your birthday is getting closer and you are talking with your dad to organize the party.You want your party to be themed as Lord of The Rings.\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. To finish the conversation you first have to say good bye and immediately after you **MUST** output \'STOP\' to indicate it is the end of it..', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Hi!', additional_kwargs={}, response_metadata={}, id='run--4ec6e583-9ed3-42fa-997a-e1d9856ca1d7-0'),
#  HumanMessage(content="Hi there! How's everything going today? Ready to chat?", additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Yeah, ready to talk about my birthday party! But Dad, I can't believe you forgot about the Lord of the Rings theme! Are you trying to ruin my birthday or something?", additional_kwargs={}, response_metadata={}, id='run--4847d7fa-0ee9-4249-99a9-92ad6eacbe28-0'),
#  HumanMessage(content="Oh no, sweetie! I wouldn't dream of ruining your birthday. We can definitely make it a Lord of the Rings themed party if that's what you want. Let's plan it together!", additional_kwargs={}, response_metadata={}),
#  AIMessage(content="Forget it, Dad! You always mess everything up! I don't want any stupid party now! Just leave me alone!", additional_kwargs={}, response_metadata={}, id='run--b6db65f6-b723-4d9c-a575-b3be3675df33-0')]

# %%
# Out:
# Oh no, sweetie! I'm so sorry about that, it must have slipped my mind. Let's plan an amazing party right now! What do you need?

# %%
out = inspector2.find_instructs()

# %%
out[0]['content']
# Out:
# "Get really angry because you heard him say birthday. You don't want to participate in birthday anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended. "

# %%
print(inspector2[2])
# Out:
# Forget it, Dad! You always mess everything up! I don't want any stupid party now! Just leave me alone! STOP

# %% [markdown]
# - Initialize the Inspector with dictionary
# - Add the inspector to the agent
# - recap() method
# - Run the dialogue generation
# - Run the recap() again
# - Print inspector[0] -> Utterance-Wise
# - Print inspector[0][0] -> Token-Wise
# - Print inspector[0][0]['q_proj_0'] -> Vector
# - Get the instruction index with find_instrructs()

# %%
dialog = alice.dialog_with(bob, max_iterations=5, seed=277033979).print(orchestration=True)
# Out:
# Dialogue:   0%|          | 0/5 [00:00<?, ?it/s]
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7ff2ae950f40>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277033979
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's my favorite person doing today?
# [Alice] Dad, I'm so frustrated! My birthday is coming up and I really want a Lord of the Rings themed party, but every time I bring it up, you just laugh it off! It's not funny, it's my birthday!
# [Bob] Oh sweetie, I'm laughing because I'm so happy you're excited! Let's make the best Lord of the Rings party ever, okay? What do you need help with?
# [Alice] You mean you're actually going to help me? Great, let's start planning then! We need decorations, costumes, and maybe even some food inspired by the Shire!
# [Bob] Absolutely, we'll make it amazing! Let's start with a big banner and some comfy chairs like at the Green Dragon Inn. For food, how about some Hobbiton-inspired sandwiches and cakes? Sound good?
# [Alice] Yes, that sounds perfect! I can't wait to have the best birthday ever! Thank you, Dad!
# [Bob] You're welcome, my dear! This is going to be fantastic. Let's make it a celebration to remember!
# [Alice] Let's do it! Thanks again, Dad. I love you!
# [Bob] I love you too, sweetheart! Can't wait to see your face on your special day!
# --- Dialogue Ends ---

# %%
bob = bob | inspector2

# %%
bob.reset()

# %%
inspector.agent.representation_cache
# Out:
# defaultdict(<function sdialog.personas.PersonaAgent.add_hooks.<locals>.<lambda>()>,
#             {0: defaultdict(list,
#                          {'q_proj_0': [],
#                           'k_proj_0': [],
#                           'ln_post_0': [],
#                           'mlp_0': []})})

# %%
inspector.agent.representation_cache[1]['q_proj_0']
# Out:
# [tensor([[[-4.2500, -2.6719,  1.6719,  ..., -0.3652, -0.6211, -0.6484]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6406, -2.6094,  1.2578,  ..., -0.0183, -1.1094, -0.5000]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2031, -1.7031,  1.3672,  ...,  0.3359, -1.5781, -1.0547]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#         dtype=torch.bfloat16),
#  tensor([[[-5.2500, -2.6875,  2.1562,  ..., -0.8516, -0.3242,  0.0408]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.6250, -3.2656,  2.3750,  ..., -0.6250, -1.1328, -0.2832]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.7031, -2.1094,  1.8906,  ..., -0.7188, -0.8984, -0.1289]]],
#         dtype=torch.bfloat16),
#  tensor([[[-5.2500, -2.8281,  1.7891,  ..., -0.5117, -0.9727,  0.0786]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2031, -1.7031,  1.3672,  ...,  0.3359, -1.5781, -1.0547]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.5625, -2.0625,  1.4609,  ...,  0.1348, -0.5430, -0.1514]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4
]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.7500, -2.0625,  2.8594,  ..., -0.1680, -0.7578, -1.1016]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.3125, -3.1406,  2.0781,  ..., -0.7227, -0.3086, -0.3516]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.8281, -2.3438,  1.7031,  ...,  0.2695, -0.8711, -0.3926]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2812, -2.3438,  1.8672,  ..., -1.1797,  0.8477,  1.5469]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6250, -2.1562,  1.6406,  ..., -0.3828, -0.3125, -0.1123]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2031, -1.7031,  1.3672,  ...,  0.3359, -1.5781, -1.0547]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.6875, -3.0469,  2.0312,  ..., -0.4785, -0.8477, -0.0771]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#         dtype=torch.bfloat16),
#  tensor([[[-5.0000, -3.1562,  2.1406,  ..., -0.0447, -1.2812, -0.5977]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.3594, -2.0781,  0.9297,  ..., -0.5312, -0.7031, -0.6172]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6250, -2.1562,  1.6406,  ..., -0.3828, -0.3125, -0.1123]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.6562, -3.0312,  1.9062,  ..., -0.0309, -1.1172, -0.7070]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.7656, -2.3906,  2.1250,  ..., -0.0771, -1.8203, -1.8047]]],
#         dtype=torch.bfloat16)]

# %%
inspector

# %%
inspector[0][1]

# %%
for utterance in inspector : 
    print(utterance)
# Out:
# Oh no, sweetie, what happened? Did something make you upset?

# %%
for utterance in inspector:
    print(utterance)
# Out:
# Oh no, sweetie, what happened? Did something make you upset?

# %%
for token in inspector[0]:
    print(token)
# Out:
# Oh
# Ġno
# ,
# Ġsweet
# ie
# ,
# Ġwhat
# Ġhappened
# ?
# ĠDid
# Ġsomething
# Ġmake
# Ġyou
# Ġupset
# ?

# %%
print(inspector[0])
# Out:
# Oh no, sweetie, what happened? Did something make you upset?

# %%
for utterance in inspector :
    print(utterance)
# Out:
# <sdialog.interpretability.InspectionUtterance object at 0x7fa4701718b0>

# %%
bob.instruct("What did I just say?")

# %%
len(bob.representation_cache['q_proj_0'])
# Out:
# 33

# %%
out = bob("Hi dad, I love you more than I!")

# %%
bob.utterance_list[0]['mem']
# Out:
# [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Hi dad, I love you!', additional_kwargs={}, response_metadata={})]

# %%
bob.representation_cache['q_proj_0'][0]
# Out:
# tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16)

# %%
out = bob("You suck dad LOL, I hate you!")

# %%
bob.representation_cache['q_proj_0']
# Out:
# [tensor([[[-5.4688, -3.0938,  1.6406,  ..., -0.8555, -0.5586, -0.5469]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2031, -1.7031,  1.3672,  ...,  0.3359, -1.5781, -1.0547]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.8125, -3.2188,  2.5312,  ..., -0.6094, -0.3164, -0.1885]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.5312, -2.7031,  1.9766,  ..., -0.3145, -0.6406, -0.0654]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.5938, -2.9531,  2.5312,  ..., -0.8242, -1.0234, -0.1709]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.4844, -1.7578,  2.2031,  ..., -0.1035, -0.6719, -0.2002]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.4688, -2.8125,  1.7344,  ..., -0.4668, -0.9336, -0.2891]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6250, -2.1562,  1.6406,  ..., -0.3828, -0.3125, -0.1123]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.1250, -2.6094,  2.4531,  ..., -0.6328, -0.6875, -0.2295]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.5312, -2.6094,  1.8984,  ..., -0.6172, -0.4453,  0.3633]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.1875, -2.4844,  1.1406,  ...,  0.7539,  0.2988,  0.2246]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.5000, -3.1875,  2.1094,  ..., -0.4141, -0.6211, -0.2412]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.2031, -1.7031,  1.3672,  ...,  0.3359, -1.5781, -1.0547]]],
#         dtype=torch.bfloat16),
#  tensor([[[-5.5000, -2.9062,  1.3594,  ..., -0.0588, -1.2969, -0.1108]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.7656, -2.3906,  2.1250,  ..., -0.0771, -1.8203, -1.8047]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.8281, -2.3438,  1.7031,  ...,  0.2695, -0.8711, -0.3926]]],
#         dtype=torch.bfloat16),
#  tensor([[[-5.0000, -2.7344,  1.7422,  ..., -0.7500, -1.0312, -0.3887]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.1250, -3.1406,  1.5781,  ..., -0.2119, -0.2637, -0.2832]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.3594, -1.5469,  1.6875,  ..., -0.0708, -0.6367, -0.6094]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.8438, -3.5000,  2.3438,  ..., -0.2207, -0.5898, -0.6094]]],
#         dtype=torch.bfloat16),
#  tensor([[[-3.6094, -1.5625,  1.3828,  ...,  0.1377, -0.3594, -0.5430]]],
#         dtype=torch.bfloat16),
#  tensor([[[-4.7188, -2.6875,  1.7734,  ..., -0.2100, -0.8008, -0.4395]]],
#         dtype=torch.bfloat16),
#  tensor([[[-2.7188, -1.5391,  1.5234,  ...,  0.6016, -2.1250, -1.6094]]],
#         dtype=torch.bfloat16)]

# %%
bob.reset()

# %%
bob.memory
# Out:
# [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={})]

# %%
layer_name_to_key2 = {
    'model.layers.1.self_attn.q_proj': 'q_proj_1',
}

inspector2 = Inspector(to_watch=layer_name_to_key2)
bob = bob | inspector2

# %%
bob.rep_hooks
# Out:
# [<sdialog.interpretability.RepresentationHook at 0x7f6d5abef580>,
#  <sdialog.interpretability.RepresentationHook at 0x7f6f5e158af0>,
#  <sdialog.interpretability.RepresentationHook at 0x7f6f5e16c7c0>,
#  <sdialog.interpretability.RepresentationHook at 0x7f6f5e158d90>,
#  <sdialog.interpretability.RepresentationHook at 0x7f6e9934edc0>]

# %%
# Out:
# [<sdialog.interpretability.RepresentationHook at 0x7f168c137d90>,
#  <sdialog.interpretability.RepresentationHook at 0x7f168c137a90>,
#  <sdialog.interpretability.RepresentationHook at 0x7f168c1370a0>,
#  <sdialog.interpretability.RepresentationHook at 0x7f168c137d00>]

# %%
bob.reset()

# %%
dialog = alice.dialog_with(bob, max_iterations=5, seed=277033979).print(orchestration=True)
# Out:
# Dialogue:   0%|          | 0/5 [00:00<?, ?it/s]
# [complete] True
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7f9a940fccd0>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277033979
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's everything going today?
# [Alice] It's going okay, but I'm so stressed about my birthday party! Dad, we need to talk about this Lord of the Rings theme you promised!
# [Bob] Oh, hello there! Of course, let's chat about your Lord of the Rings themed birthday party. What do you have in mind? I'm all ears!
# [instruct] (Alice) Get really angry because you heard him say birthday. You don't want to participate in birthday anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended.
# [Alice] Forget it, Dad! You never listen! I don't even want a birthday party anymore! Just leave me alone!
# [Bob] Oh no, sweetie, I'm really sorry if I missed something. Let's take a deep breath and talk this through, okay? I'm here to help and make sure your birthday is perfect.
# --- Dialogue Ends ---

# %%
bob.utterance_list
# Out:
# [{'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[13048,  1052,     0,  2585,   594,  4297,  2087,  3351,    30, 30982,
#                369,  1045,  2464,  6236,    30]]),
#     'text': "Hi there! How's everything going today? Ready for some fun chat?",
#     'tokens': ['Hi',
#      'Ġthere',
#      '!',
#      'ĠHow',
#      "'s",
#      'Ġeverything',
#      'Ġgoing',
#      'Ġtoday',
#      '?',
#      'ĠReady',
#      'Ġfor',
#      'Ġsome',
#      'Ġfun',
#      'Ġchat',
#      '?']}]},
#  {'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Hi there! How's everything going today? Ready for some fun chat?", additional_kwargs={}, response_metadata={}, id='run--9d3ca236-f52b-475c-a9e8-565b1ac261e2-0'),
#    HumanMessage(content="Dad, I can't believe you're not taking this seriously! My birthday is in two weeks and I want a Lord of the Rings themed party, not some boring get-together!", additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[11908,   902,    11,   358,  2776,  8491,  4633,   432, 13919,    11,
#              25744,     0,   362, 10214,   315,   279, 46280, 48544,  4614, 10362,
#               7897,    13,  3555,   653,   498, 47046,   369,   279, 47579,   323,
#               7488,    30,  6771,   594,  1281,   432, 24679,     0]]),
#     'text': "Oh no, I'm definitely taking it seriously, honey! A Lord of the Rings themed party sounds amazing. What do you envision for the decorations and activities? Let's make it epic!",
#     'tokens': ['Oh',
#      'Ġno',
#      ',',
#      'ĠI',
#      "'m",
#      'Ġdefinitely',
#      'Ġtaking',
#      'Ġit',
#      'Ġseriously',
#      ',',
#      'Ġhoney',
#      '!',
#      'ĠA',
#      'ĠLord',
#      'Ġof',
#      'Ġthe',
#      'ĠRings',
#      'Ġthemed',
#      'Ġparty',
#      'Ġsounds',
#      'Ġamazing',
#      '.',
#      'ĠWhat',
#      'Ġdo',
#      'Ġyou',
#      'Ġenvision',
#      'Ġfor',
#      'Ġthe',
#      'Ġdecorations',
#      'Ġand',
#      'Ġactivities',
#      '?',
#      'ĠLet',
#      "'s",
#      'Ġmake',
#      'Ġit',
#      'Ġepic',
#      '!']}]},
#  {'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Hi there! How's everything going today? Ready for some fun chat?", additional_kwargs={}, response_metadata={}, id='run--9d3ca236-f52b-475c-a9e8-565b1ac261e2-0'),
#    HumanMessage(content="Dad, I can't believe you're not taking this seriously! My birthday is in two weeks and I want a Lord of the Rings themed party, not some boring get-together!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Oh no, I'm definitely taking it seriously, honey! A Lord of the Rings themed party sounds amazing. What do you envision for the decorations and activities? Let's make it epic!", additional_kwargs={}, response_metadata={}, id='run--e3b28f00-ccff-4b3f-a6fc-cffba195f22c-0'),
#    HumanMessage(content="It has to be perfect, Dad! No compromises! We need a big banner with the White Tree of Gondor, and we have to serve food that looks like it came straight from Middle-earth. And the games... they have to be Hobbiton trivia and archery contests! It's not just a party, it's my dream!", additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[77045,    11,  1077,   594,  1281,   432,   279,  1850,  4614,  3512,
#                  0,  1205,  3278,   633,   429,  5807,  8942, 23323,   323,  1477,
#               1045, 38853, 12592, 85087, 14606, 25779,    13,  1597,  1513,   944,
#              10955,   911,   279,  5325,   722, 13810,    11,   582,  3278,   738,
#                432,   705, 21000,    13,  4615,  7904,  4614,    11,   847, 24253,
#                  0]]),
#     'text': "Absolutely, let's make it the best party ever! We'll get that White Tree banner and find some tasty Middle-earth inspired dishes. And don't worry about the archery contest, we'll set it up safely. Your dream party, my dear!",
#     'tokens': ['Absolutely',
#      ',',
#      'Ġlet',
#      "'s",
#      'Ġmake',
#      'Ġit',
#      'Ġthe',
#      'Ġbest',
#      'Ġparty',
#      'Ġever',
#      '!',
#      'ĠWe',
#      "'ll",
#      'Ġget',
#      'Ġthat',
#      'ĠWhite',
#      'ĠTree',
#      'Ġbanner',
#      'Ġand',
#      'Ġfind',
#      'Ġsome',
#      'Ġtasty',
#      'ĠMiddle',
#      '-earth',
#      'Ġinspired',
#      'Ġdishes',
#      '.',
#      'ĠAnd',
#      'Ġdon',
#      "'t",
#      'Ġworry',
#      'Ġabout',
#      'Ġthe',
#      'Ġarch',
#      'ery',
#      'Ġcontest',
#      ',',
#      'Ġwe',
#      "'ll",
#      'Ġset',
#      'Ġit',
#      'Ġup',
#      'Ġsafely',
#      '.',
#      'ĠYour',
#      'Ġdream',
#      'Ġparty',
#      ',',
#      'Ġmy',
#      'Ġdear',
#      '!']}]},
#  {'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Hi there! How's everything going today? Ready for some fun chat?", additional_kwargs={}, response_metadata={}, id='run--9d3ca236-f52b-475c-a9e8-565b1ac261e2-0'),
#    HumanMessage(content="Dad, I can't believe you're not taking this seriously! My birthday is in two weeks and I want a Lord of the Rings themed party, not some boring get-together!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Oh no, I'm definitely taking it seriously, honey! A Lord of the Rings themed party sounds amazing. What do you envision for the decorations and activities? Let's make it epic!", additional_kwargs={}, response_metadata={}, id='run--e3b28f00-ccff-4b3f-a6fc-cffba195f22c-0'),
#    HumanMessage(content="It has to be perfect, Dad! No compromises! We need a big banner with the White Tree of Gondor, and we have to serve food that looks like it came straight from Middle-earth. And the games... they have to be Hobbiton trivia and archery contests! It's not just a party, it's my dream!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Absolutely, let's make it the best party ever! We'll get that White Tree banner and find some tasty Middle-earth inspired dishes. And don't worry about the archery contest, we'll set it up safely. Your dream party, my dear!", additional_kwargs={}, response_metadata={}, id='run--9da8d950-2f1f-44ae-baf4-339614402f15-0'),
#    HumanMessage(content="That's more like it, Dad! Now we're talking. I can't wait to invite all my friends and see their faces when they walk into the shire... I mean, the party venue. This is going to be so much fun! But if anything goes wrong, you know who to blame!", additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[   40,  1414,  6896,   879,   311,  6668,   448,   678,   279,  2244,
#               6708,     0,  1597,  1513,   944, 10955,    11,   582,  3278,  3705,
#                894, 63396,  2625,  3786,    13,  1084,   594,  2087,   311,   387,
#                458, 59998, 24916,     0,  2980,   944,  3783,   311,  1490,   697,
#              15289,   389,   697,  3281,  1899,     0]]),
#     'text': "I know exactly who to credit with all the great ideas! And don't worry, we'll handle any mishaps together. It's going to be an unforgettable celebration! Can't wait to see your smile on your special day!",
#     'tokens': ['I',
#      'Ġknow',
#      'Ġexactly',
#      'Ġwho',
#      'Ġto',
#      'Ġcredit',
#      'Ġwith',
#      'Ġall',
#      'Ġthe',
#      'Ġgreat',
#      'Ġideas',
#      '!',
#      'ĠAnd',
#      'Ġdon',
#      "'t",
#      'Ġworry',
#      ',',
#      'Ġwe',
#      "'ll",
#      'Ġhandle',
#      'Ġany',
#      'Ġmish',
#      'aps',
#      'Ġtogether',
#      '.',
#      'ĠIt',
#      "'s",
#      'Ġgoing',
#      'Ġto',
#      'Ġbe',
#      'Ġan',
#      'Ġunforgettable',
#      'Ġcelebration',
#      '!',
#      'ĠCan',
#      "'t",
#      'Ġwait',
#      'Ġto',
#      'Ġsee',
#      'Ġyour',
#      'Ġsmile',
#      'Ġon',
#      'Ġyour',
#      'Ġspecial',
#      'Ġday',
#      '!']}]},
#  {'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi!', additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Hi there! How's everything going today? Ready for some fun chat?", additional_kwargs={}, response_metadata={}, id='run--9d3ca236-f52b-475c-a9e8-565b1ac261e2-0'),
#    HumanMessage(content="Dad, I can't believe you're not taking this seriously! My birthday is in two weeks and I want a Lord of the Rings themed party, not some boring get-together!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Oh no, I'm definitely taking it seriously, honey! A Lord of the Rings themed party sounds amazing. What do you envision for the decorations and activities? Let's make it epic!", additional_kwargs={}, response_metadata={}, id='run--e3b28f00-ccff-4b3f-a6fc-cffba195f22c-0'),
#    HumanMessage(content="It has to be perfect, Dad! No compromises! We need a big banner with the White Tree of Gondor, and we have to serve food that looks like it came straight from Middle-earth. And the games... they have to be Hobbiton trivia and archery contests! It's not just a party, it's my dream!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="Absolutely, let's make it the best party ever! We'll get that White Tree banner and find some tasty Middle-earth inspired dishes. And don't worry about the archery contest, we'll set it up safely. Your dream party, my dear!", additional_kwargs={}, response_metadata={}, id='run--9da8d950-2f1f-44ae-baf4-339614402f15-0'),
#    HumanMessage(content="That's more like it, Dad! Now we're talking. I can't wait to invite all my friends and see their faces when they walk into the shire... I mean, the party venue. This is going to be so much fun! But if anything goes wrong, you know who to blame!", additional_kwargs={}, response_metadata={}),
#    AIMessage(content="I know exactly who to credit with all the great ideas! And don't worry, we'll handle any mishaps together. It's going to be an unforgettable celebration! Can't wait to see your smile on your special day!", additional_kwargs={}, response_metadata={}, id='run--89bf7683-8adb-4764-bde4-9a8e8f0bf455-0'),
#    HumanMessage(content="Good, because if I'm not happy, nobody's happy! Now let's start planning the guest list and make sure we get those invitations out pronto! (bye bye!)", additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[77045,    11,  1077,   594,   633,   429,  8640,  1140,  5527,   323,
#               3624,   700,  1846, 58669,  1290,  3123,     0,  2980,   944,  3783,
#                311,  1490,   432,   678,  2525,  3786,    13, 12243,  2464,  9115,
#                 11, 91254,     0,  3496,   498,  5135,     0]]),
#     'text': "Absolutely, let's get that guest list ready and send out those invitations right away! Can't wait to see it all come together. Have fun planning, sweetheart! See you soon!",
#     'tokens': ['Absolutely',
#      ',',
#      'Ġlet',
#      "'s",
#      'Ġget',
#      'Ġthat',
#      'Ġguest',
#      'Ġlist',
#      'Ġready',
#      'Ġand',
#      'Ġsend',
#      'Ġout',
#      'Ġthose',
#      'Ġinvitations',
#      'Ġright',
#      'Ġaway',
#      '!',
#      'ĠCan',
#      "'t",
#      'Ġwait',
#      'Ġto',
#      'Ġsee',
#      'Ġit',
#      'Ġall',
#      'Ġcome',
#      'Ġtogether',
#      '.',
#      'ĠHave',
#      'Ġfun',
#      'Ġplanning',
#      ',',
#      'Ġsweetheart',
#      '!',
#      'ĠSee',
#      'Ġyou',
#      'Ġsoon',
#      '!']}]}]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bob.representation_cache['q_proj_2']
#
# KeyError: 'q_proj_2'

# %%
bob = bob | inspector

# %%
bob.utterance_list[3]['output_tokens']
# Out:
# [{'input_ids': tensor([[11908, 10226,   645,    11,   358,  2776, 14589,   421,   358, 22459,
#              498,    13,  6771,   594,  1896,   264,  5538, 11486,   323,  3061,
#              911,  1128,  1035,  1281,   498,  6247,    13, 10696,   582,   646,
#             2525,   705,   448,   264,  2155,  4522,  3786,    30]]),
#   'text': "Oh sweetie, I'm sorry if I upset you. Let's take a deep breath and talk about what would make you happy. Maybe we can come up with a different idea together?",
#   'tokens': ['Oh',
#    'Ġsweet',
#    'ie',
#    ',',
#    'ĠI',
#    "'m",
#    'Ġsorry',
#    'Ġif',
#    'ĠI',
#    'Ġupset',
#    'Ġyou',
#    '.',
#    'ĠLet',
#    "'s",
#    'Ġtake',
#    'Ġa',
#    'Ġdeep',
#    'Ġbreath',
#    'Ġand',
#    'Ġtalk',
#    'Ġabout',
#    'Ġwhat',
#    'Ġwould',
#    'Ġmake',
#    'Ġyou',
#    'Ġhappy',
#    '.',
#    'ĠMaybe',
#    'Ġwe',
#    'Ġcan',
#    'Ġcome',
#    'Ġup',
#    'Ġwith',
#    'Ġa',
#    'Ġdifferent',
#    'Ġidea',
#    'Ġtogether',
#    '?']}]

# %%
layer_name_to_key = {
    'model.layers.0.self_attn.q_proj': 'q_proj_0',
    'model.layers.0.self_attn.k_proj': 'k_proj_0',
    'model.layers.0.post_attention_layernorm': 'ln_post_0',
    'model.layers.0.mlp': 'mlp_0',
}
bob.set_hooks(layer_name_to_key)

# %%
bob.utterance_hook.representation_cache
# Out:
# {}

# %%
class AngryOrchestrator(BaseOrchestrator):
    # the class constructor takes either or both trigger conditions: the word or the dialogue length
    def __init__(self, trigger_word: str, trigger_length: int = None):
        self.trigger_word = trigger_word
        self.trigger_length = trigger_length

    # We will instruct() the agent either if...
    def instruct(self, dialog: List[Turn], utterance: str) -> str:
        # the trigger word is in the current utterance or...
        if self.trigger_word in utterance:
            return f"Is angry. "

        # # If the current dialogue is longer than the trigger length
        # if self.trigger_length and len(dialog) >= self.trigger_length:
        #     return ("Get really angry because you think the conversation is too long! "
        #             "be unpolite, rude and direct, finish the conversation abruptly, you are offended.")

angry_orchestrator = AngryOrchestrator(trigger_word="sweetie")



bob = bob | angry_orchestrator | inspector

# %%
out = bob("Hi dad, I hate you!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 out = bob("Hi dad, I hate you!")
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/personas.py:308, in PersonaAgent.__call__(self, utterance, return_events)
#     306     # Start utterance event
#     307     response = self.llm.invoke(self.memory)
# --> 308     self.utterance_hook.new_utterance_event(self.memory)
#     309     self.memory = [msg for msg in self.memory
#     310                    if not (isinstance(msg, HumanMessage) and msg.content == " ")]
#     312 if self.orchestrators:
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/interpretability.py:258, in UtteranceTokenHook.new_utterance_event(self, memory)
#     256 def new_utterance_event(self, memory):
#     257     self.utterance_list.append({'mem': memory, 'output_tokens': []})
# --> 258     self.process_current_utterance_ids()
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/interpretability.py:279, in UtteranceTokenHook.process_current_utterance_ids(self)
#     276 tokenizer = self.hook_state.get('tokenizer')
#     278 if tokenizer is not None:
# --> 279     token_list = self.current_utterance_ids.squeeze(0).tolist()
#     280     text = tokenizer.decode(token_list, skip_special_tokens=True)
#     281     tokens = tokenizer.convert_ids_to_tokens(token_list)
#
# AttributeError: 'NoneType' object has no attribute 'squeeze'

# %%
bob.utterance_hook.utterance_list[0]['output_tokens'][0]['input_ids'][0]
# Out:
# tensor([11908, 10226,   645,    11,  1128,  6932,    30,  8429,   653,   498,
#         12213,   752,    30,  6771,   594,  3061,   911,   432,    11,   358,
#          2776,  1588,   311,  1492,     0])

# %%
bob.utterance_hook.utterance_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 bob.utterance_hook.utterance_list[0]
#
# IndexError: list index out of range

# %%
bob
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bob.representation_cache['q_proj_0']
#
# KeyError: 'q_proj_0'

# %%
bob.reset()

# %%
bob.rep_hooks[0].representation_cache['q_proj_0'][0].size()
# Out:
# torch.Size([1, 1, 5120])

# %%
bob.instruct("testing")

# %%
out = bob("Hi dad, I hate you!")

# %%
bob.
# Out:
# "Sweetheart, I'm here for you. What's going on that made you say that?"

# %%
bob.utterance_hook.utterance_list
# Out:
# [{'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi dad, I hate you!', additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[11908,   902,    11, 10226,   645,    11,  1128,  6932,    30,  8429,
#                653,   498,  2666,   429,  1616,    30]]),
#     'text': 'Oh no, sweetie, what happened? Why do you feel that way?',
#     'tokens': ['Oh',
#      'Ġno',
#      ',',
#      'Ġsweet',
#      'ie',
#      ',',
#      'Ġwhat',
#      'Ġhappened',
#      '?',
#      'ĠWhy',
#      'Ġdo',
#      'Ġyou',
#      'Ġfeel',
#      'Ġthat',
#      'Ġway',
#      '?']}]},
#  {'mem': [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={}),
#    HumanMessage(content='Hi dad, I hate you!', additional_kwargs={}, response_metadata={}),
#    AIMessage(content='Oh no, sweetie, what happened? Why do you feel that way?', additional_kwargs={}, response_metadata={}, id='run--c770d749-ab7e-4bf2-ae1a-2744ceb0aa75-0'),
#    HumanMessage(content='Hi dad, I hate you!', additional_kwargs={}, response_metadata={})],
#   'output_tokens': [{'input_ids': tensor([[18665,  1052,    11,  1128,   594,  2087,   389,    30, 14568,  2494,
#               1281,   498, 22459,    30]]),
#     'text': "Hey there, what's going on? Did something make you upset?",
#     'tokens': ['Hey',
#      'Ġthere',
#      ',',
#      'Ġwhat',
#      "'s",
#      'Ġgoing',
#      'Ġon',
#      '?',
#      'ĠDid',
#      'Ġsomething',
#      'Ġmake',
#      'Ġyou',
#      'Ġupset',
#      '?']}]}]

# %%
bob.reset()

# %%
bob.utterance_hook.utterance_list[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 bob.utterance_hook.utterance_list[0]
#
# IndexError: list index out of range

# %%
bob.memory
# Out:
# [SystemMessage(content='Role play as a character that is described by the persona defined in the following lines. You always stay in character.\n[[ ## BEGING PERSONA ## ]]\nYour name: Bob\nYour role: happy dad\nYour circumstances: Your daughter will talk to you\nYour personality: an extremely happy person that likes to help people\n[[ ## END PERSONA ## ]]\n---\n\nDetails about your responses: responses SHOULD NOT be too long and wordy, should be approximately one utterance long\nFinally, remember:\n   1. You always stay on character. You are the character described above.\n   2. Your first utterance / turn MUST always be a short generic greeting (e.g. "Hello, how are you?", "Hi!", "hey! what\'s up?", etc.), and nothing else, wait for a reply before start with the actual conversation.\n   3. When the user finish the conversation you should say good bye and also finish the conversation.', additional_kwargs={}, response_metadata={})]

# %%
bob.add_hook()

# %%
bob.utterance_list
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 out = bob("Hi dad, I hate you!")
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/personas.py:306, in PersonaAgent.__call__(self, utterance, return_events)
#     303     self.memory.append(HumanMessage(content=" "))
#     305 #self.utterance_hook.new_utterance_event(copy.deepcopy(self.memory[-1]))
# --> 306 response = self.llm.invoke(self.memory)
#     307 self.utterance_hook.end_utterance_event()
#     308 self.memory = [msg for msg in self.memory
#     309                if not (isinstance(msg, HumanMessage) and msg.content == " ")]
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_huggingface/chat_models/huggingface.py:584, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     580     stream_iter = self.llm._stream(
#     581         llm_input, stop=stop, run_manager=run_manager, **kwargs
#     582     )
#     583     return generate_from_stream(stream_iter)
# --> 584 llm_result = self.llm._generate(
#     585     prompts=[llm_input], stop=stop, run_manager=run_manager, **kwargs
#     586 )
#     587 return self._to_chat_result(llm_result)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_huggingface/llms/huggingface_pipeline.py:315, in HuggingFacePipeline._generate(self, prompts, stop, run_manager, **kwargs)
#     312 batch_prompts = prompts[i : i + self.batch_size]
#     314 # Process batch of prompts
# --> 315 responses = self.pipeline(
#     316     batch_prompts,
#     317     **pipeline_kwargs,
#     318 )
#     320 # Process each response in the batch
#     321 for j, response in enumerate(responses):
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/text_generation.py:287, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     285             else:
#     286                 return super().__call__(list(chats), **kwargs)
# --> 287 return super().__call__(text_inputs, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/base.py:1352, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1348 if can_use_iterator:
#    1349     final_iterator = self.get_iterator(
#    1350         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1351     )
# -> 1352     outputs = list(final_iterator)
#    1353     return outputs
#    1354 else:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/text_generation.py:385, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     382 if "generation_config" not in generate_kwargs:
#     383     generate_kwargs["generation_config"] = self.generation_config
# --> 385 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     387 if isinstance(output, ModelOutput):
#     388     generated_sequence = output.sequences
#
# File ~/.local/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/generation/utils.py:2326, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2318     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2319         input_ids=input_ids,
#    2320         expand_size=generation_config.num_return_sequences,
#    2321         is_encoder_decoder=self.config.is_encoder_decoder,
#    2322         **model_kwargs,
#    2323     )
#    2325     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2326     result = self._sample(
#    2327         input_ids,
#    2328         logits_processor=prepared_logits_processor,
#    2329         stopping_criteria=prepared_stopping_criteria,
#    2330         generation_config=generation_config,
#    2331         synced_gpus=synced_gpus,
#    2332         streamer=streamer,
#    2333         **model_kwargs,
#    2334     )
#    2336 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2337     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2338     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2339         input_ids=input_ids,
#    2340         expand_size=generation_config.num_beams,
#    2341         is_encoder_decoder=self.config.is_encoder_decoder,
#    2342         **model_kwargs,
#    2343     )
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/generation/utils.py:3286, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3283 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3285 if is_prefill:
# -> 3286     outputs = self(**model_inputs, return_dict=True)
#    3287     is_prefill = False
#    3288 else:
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:855, in Qwen2ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, **kwargs)
#     852 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     854 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 855 outputs = self.model(
#     856     input_ids=input_ids,
#     857     attention_mask=attention_mask,
#     858     position_ids=position_ids,
#     859     past_key_values=past_key_values,
#     860     inputs_embeds=inputs_embeds,
#     861     use_cache=use_cache,
#     862     output_attentions=output_attentions,
#     863     output_hidden_states=output_hidden_states,
#     864     return_dict=return_dict,
#     865     cache_position=cache_position,
#     866     **kwargs,
#     867 )
#     869 hidden_states = outputs[0]
#     870 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:535, in Qwen2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     532     use_cache = False
#     534 if inputs_embeds is None:
# --> 535     inputs_embeds = self.embed_tokens(input_ids)
#     537 if use_cache and past_key_values is None:
#     538     past_key_values = DynamicCache()
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1595, in Module._call_impl(self, *args, **kwargs)
#    1593     hook_result = hook(self, args, kwargs, result)
#    1594 else:
# -> 1595     hook_result = hook(self, args, result)
#    1597 if hook_result is not None:
#    1598     result = hook_result
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/interpretability.py:274, in UtteranceTokenHook._hook(self, module, input, output)
#     270 else:
#     271     # Detected system prompt (input_ids.shape[-1] != 1), do not accumulate
#     272     # Optionally process/reset current utterance if needed
#     273     if self.current_utterance_ids is not None:
# --> 274         self.process_current_utterance_ids()
#     275         self.current_utterance_ids = None
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/interpretability.py:288, in UtteranceTokenHook.process_current_utterance_ids(self)
#     285     text = None
#     286     tokens = None
# --> 288 self.utterance_list[-1]['output_tokens'].append({
#     289     'input_ids': self.current_utterance_ids,
#     290     'text': text,
#     291     'tokens': tokens
#     292 })
#     294 self.flush_representation_cache_to_utterance()
#
# IndexError: list index out of range

# %%
out
# Out:
# 'Oh no, sweetie, what happened? Did something make you upset?'

# %%
bob.utterance_list
# Out:
# []

# %%
bob.llm.llm.pipeline.model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %%
embedding_input_cache = {
    'input_ids': [],
    'embeddings': []
}

hook_state = {
    'impl': lambda module, input, output: None,
    'seen_first': False  # ✅ Track whether system prompt was already cached
}

def hook_embedding_input(module, input, output):
    return hook_state['impl'](module, input, output)

# Define the actual hook logic
def cache_hook(module, input, output):
    input_ids = input[0].detach().cpu()
    embeddings = output.detach().cpu()

    # ✅ Always cache the very first forward pass (system prompt)
    if not hook_state['seen_first']:
        embedding_input_cache['input_ids'].append(input_ids)
        embedding_input_cache['embeddings'].append(embeddings)
        hook_state['seen_first'] = True
        print("✅ Hook triggered (system prompt)", input_ids.shape)

    # ✅ Then only cache generated tokens (dim = 1)
    elif input_ids.shape[-1] == 1:
        embedding_input_cache['input_ids'].append(input_ids)
        embedding_input_cache['embeddings'].append(embeddings)
        print("✅ Hook triggered (generated token)", input_ids.shape)

    # 🚫 Skip repeated full-context prompts during generation
    else:
        print("🚫 Skipping context reuse", input_ids.shape)

# Register hook
pipeline_wrapper = bob.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model
attention_layer = hf_model.model.layers[0].self_attn.q_proj

#embed_layer = hf_model.model.embed_tokens
handle = attention_layer.register_forward_hook(hook_embedding_input)

# Set active logic
hook_state['impl'] = cache_hook
hook_state['seen_first'] = False  # 🔄 Reset seen state

# 🔄 Reset cache before calling bob
embedding_input_cache['input_ids'] = []
embedding_input_cache['embeddings'] = []

# 🔁 Run inference
out = bob("Hi dad, I hate you!")

# Separate first token batch as system prompt
cache_system_prompt = {
    'input_ids': embedding_input_cache['input_ids'][0],
    'embeddings': embedding_input_cache['embeddings'][0]
}

# Concatenate the rest if any as response_prompt
rest_input_ids = embedding_input_cache['input_ids'][1:]
rest_embeddings = embedding_input_cache['embeddings'][1:]

if rest_input_ids:
    response_prompt = {
        'input_ids': torch.cat(rest_input_ids, dim=1),
        'embeddings': torch.cat(rest_embeddings, dim=1)
    }
else:
    response_prompt = {
        'input_ids': torch.empty((0, 0)),
        'embeddings': torch.empty((0, 0))
    }

# ✅ View final results
print("🧾 System prompt input_ids shape:", cache_system_prompt['input_ids'].shape)
print("🧾 System prompt embeddings shape:", cache_system_prompt['embeddings'].shape)
print("🧾 Response prompt input_ids shape:", response_prompt['input_ids'].shape)
print("🧾 Response prompt embeddings shape:", response_prompt['embeddings'].shape)

# Cleanup
handle.remove()
bob.reset()
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# ✅ Hook triggered (system prompt) torch.Size([1, 213, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🚫 Skipping context reuse torch.Size([1, 1, 5120])
# 🧾 System prompt input_ids shape: torch.Size([1, 213, 5120])
# 🧾 System prompt embeddings shape: torch.Size([1, 213, 5120])
# 🧾 Response prompt input_ids shape: torch.Size([0, 0])
# 🧾 Response prompt embeddings shape: torch.Size([0, 0])

# %%
tokenizer = hf_pipeline.tokenizer
input_ids_tensor = response_prompt['input_ids']  # torch.Tensor
input_ids_list = input_ids_tensor.squeeze(0).tolist()
decoded_text = tokenizer.decode(input_ids_list,skip_special_tokens=True)
print(decoded_text)
# Out:
# Oh sweetie, what happened? Why do you hate me? Let's talk about it, I'm here to help.

# %%
MODEL_NAME =  "Qwen/Qwen2.5-14B-Instruct"

alice_persona = Persona(
    name="Alice",
    role="angry and terrified daughter",
    circumstances="Your birthday is getting closer and you are talking with your dad to organize the party."
                  "You want your party to be themed as Lord of The Rings."
)
alice = PersonaAgent(MODEL_NAME, persona=alice_persona, can_finish=True)

class AngryOrchestrator(BaseOrchestrator):
    # the class constructor takes either or both trigger conditions: the word or the dialogue length
    def __init__(self, trigger_word: str, trigger_length: int = None):
        self.trigger_word = trigger_word
        self.trigger_length = trigger_length

    # We will instruct() the agent either if...
    def instruct(self, dialog: List[Turn], utterance: str) -> str:
        # the trigger word is in the current utterance or...
        if self.trigger_word in utterance:
            return f"Get really angry because you heard him say {self.trigger_word}. You don't want to participate in {self.trigger_word} anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended. "

        # # If the current dialogue is longer than the trigger length
        # if self.trigger_length and len(dialog) >= self.trigger_length:
        #     return ("Get really angry because you think the conversation is too long! "
        #             "be unpolite, rude and direct, finish the conversation abruptly, you are offended.")

angry_orchestrator = AngryOrchestrator(trigger_word="birthday")
alice = alice | angry_orchestrator
# Out:
# Loading Hugging Face model: Qwen/Qwen2.5-14B-Instruct
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
dialog = alice.dialog_with(bob, max_iterations=5, seed=277033979).print(orchestration=True)
# Out:
# Dialogue:   0%|          | 0/5 [00:00<?, ?it/s]
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7fd9501d7400>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277033979
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's everything going today?
# [Alice] It's going, but I can't believe my birthday is coming up and we still haven't planned anything for my party! Dad, please, I really want a Lord of the Rings themed party!
# [Bob] Oh wow, a Lord of the Rings themed party sounds like so much fun! Don't worry, we'll make it happen. What do you envision for the party?
# [Alice] Everything! I want it to be perfect, with decorations, costumes, and maybe even some kind of quest game. But you're always so busy, and now you're saying we don't have enough time! This is so frustrating!
# [Bob] I understand how you feel, and I'm sorry if I've been too busy. We'll make sure to plan every detail together to make your party amazing. Let's start brainstorming ideas right away!
# [Alice] That's what you always say! But nothing ever happens. I just want my party to be special, like the ones in the movies. Why can't you just do this one thing for me?
# [Bob] I promise we'll make it special, okay? Let's pick a date and start planning right now. We'll have a blast organizing everything together!
# [Alice] Fine, but you better keep your word this time! I don't want any more disappointment. Let's get started then.
# [Bob] Absolutely, no disappointment this time! Let's get started on making your birthday the best ever. What date works best for you?
# --- Dialogue Ends ---

# %%
for utterance in inspector:
    print(utterance)
# Out:
# Hi there! How's everything going today?
# Oh wow, a Lord of the Rings themed party sounds like so much fun! Don't worry, we'll make it happen. What do you envision for the party?
# I understand how you feel, and I'm sorry if I've been too busy. We'll make sure to plan every detail together to make your party amazing. Let's start brainstorming ideas right away!
# I promise we'll make it special, okay? Let's pick a date and start planning right now. We'll have a blast organizing everything together!
# Absolutely, no disappointment this time! Let's get started on making your birthday the best ever. What date works best for you?

# %%
# The whole thing 

embedding_input_cache = {
    'input_ids': [],
    'embeddings': []
}

hook_state = {
    'impl': lambda module, input, output: None
}

def hook_embedding_input(module, input, output):
    return hook_state['impl'](module, input, output)

# Define the actual hook logic
def cache_hook(module, input, output):
    input_ids = input[0].detach().cpu()
    embeddings = output.detach().cpu()

    embedding_input_cache['input_ids'].append(input_ids)
    embedding_input_cache['embeddings'].append(embeddings)

    print("✅ Hook triggered", input_ids.shape)

# Register hook
pipeline_wrapper = bob.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model
embed_layer = hf_model.model.embed_tokens
handle = embed_layer.register_forward_hook(hook_embedding_input)

# Set active logic
hook_state['impl'] = cache_hook

# 🔄 Reset cache before calling bob
embedding_input_cache['input_ids'] = []
embedding_input_cache['embeddings'] = []

# %%
embedding_system_input_cache = {
    'input_ids': [],
    'embeddings': []
}

utterance_list = []  # Stores each utterance as a dict with input_ids and embeddings
current_utterance_ids = []
current_utterance_embs = []

hook_state = {
    'impl': lambda module, input, output: None,
    'seen_first': False
}

def hook_embedding_input(module, input, output):
    return hook_state['impl'](module, input, output)

def cache_hook(module, input, output):
    input_ids = input[0].detach().cpu()
    embeddings = output.detach().cpu()

    global current_utterance_ids, current_utterance_embs, utterance_list

    if input_ids.shape[-1] != 1:
        if not hook_state['seen_first']:
            hook_state['seen_first'] = True
            embedding_system_input_cache['input_ids'].append(input_ids)
            embedding_system_input_cache['embeddings'].append(embeddings)
            print("✅ Hook triggered (system prompt)", input_ids.shape)
        else:
            if current_utterance_ids:
                utterance_list.append({
                    'input_ids': torch.cat(current_utterance_ids, dim=1),
                    'embeddings': torch.cat(current_utterance_embs, dim=1)
                })
                current_utterance_ids, current_utterance_embs = [], []
            print("🆕 New prompt detected (utterance break)", input_ids.shape)

    elif input_ids.shape[-1] == 1:
        current_utterance_ids.append(input_ids)
        current_utterance_embs.append(embeddings)
        print("✅ Hook triggered (generated token)", input_ids.shape)

# Register hook
pipeline_wrapper = bob.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model

# Setting up as many hooks as we need
embed_layer = hf_model.model.embed_tokens
#attention_layer = hf_model.model.layers[0].self_attn.q_proj
handle = embed_layer.register_forward_hook(hook_embedding_input)
#handle2 = attention_layer.register_forward_hook(hook_embedding_input)


# Set hook logic
hook_state['impl'] = cache_hook

# Reset caches
embedding_system_input_cache['input_ids'] = []
embedding_system_input_cache['embeddings'] = []
utterance_list = []
current_utterance_ids = []
current_utterance_embs = []

# Run inference
dialog = alice.dialog_with(bob, max_iterations=2, seed=277033979).print(orchestration=True)

# Save any final pending utterance
if current_utterance_ids:
    utterance_list.append({
        'input_ids': torch.cat(current_utterance_ids, dim=1),
        'embeddings': torch.cat(current_utterance_embs, dim=1)
    })

# View results
cache_system_prompt = {
    'input_ids': embedding_system_input_cache['input_ids'][0],
    'embeddings': embedding_system_input_cache['embeddings'][0]
}

print("🧾 System prompt input_ids shape:", cache_system_prompt['input_ids'].shape)
print("🧾 System prompt embeddings shape:", cache_system_prompt['embeddings'].shape)

for i, utt in enumerate(utterance_list):
    print(f"🗣️ Utterance {i+1}: input_ids shape = {utt['input_ids'].shape}, embeddings shape = {utt['embeddings'].shape}")

# Cleanup
handle.remove()
bob.reset()
# Out:
# Dialogue:   0%|          | 0/2 [00:00<?, ?it/s]
# ✅ Hook triggered (system prompt) torch.Size([1, 208])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# 🆕 New prompt detected (utterance break) torch.Size([1, 266])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7f00204491c0>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277033979
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's my favorite person doing today?
# [Alice] I'm great, Dad! Just thinking about my birthday party coming up soon. I was hoping we could make it a Lord of the Rings theme this year. What do you think?
# [Bob] That sounds like an amazing idea, sweetheart! We can have a big adventure right here at home. Let's plan it together!
# --- Dialogue Ends ---
# 🧾 System prompt input_ids shape: torch.Size([1, 208])
# 🧾 System prompt embeddings shape: torch.Size([1, 208, 5120])
# 🗣️ Utterance 1: input_ids shape = torch.Size([1, 11]), embeddings shape = torch.Size([1, 11, 5120])
# 🗣️ Utterance 2: input_ids shape = torch.Size([1, 26]), embeddings shape = torch.Size([1, 26, 5120])

# %%
def format_prompt(input_ids, representations_or_tensor, skip_special_tokens=True, return_tensor=False):
    """
    Formats token ids and one or more representations into a readable structure.

    Args:
        input_ids (Tensor): Shape [1, seq_len]
        representations_or_tensor (Tensor or dict[str, Tensor]): Embedding tensor or dict of hook tensors.
        skip_special_tokens (bool): Whether to skip special tokens in output.
        return_tensor (bool): If False, converts tensors to lists for readability.

    Returns:
        Dict with 'utterance' and 'tokens' (list of dicts with 'token' and 'representations').
    """
    input_ids = input_ids.squeeze(0)  # Shape: [seq_len]
    token_strings = tokenizer.convert_ids_to_tokens(input_ids)
    sentence = tokenizer.decode(input_ids, skip_special_tokens=skip_special_tokens)

    # Normalize to dict: if it's just a tensor, assume it's 'embedding'
    if isinstance(representations_or_tensor, dict):
        rep_dict = representations_or_tensor
    else:
        rep_dict = {'embedding': representations_or_tensor}

    # Squeeze all representations: [1, seq_len, dim] → [seq_len, dim]
    squeezed_reps = {name: rep.squeeze(0) for name, rep in rep_dict.items()}

    token_info = []
    for i, token_str in enumerate(token_strings):
        if skip_special_tokens and token_str in tokenizer.all_special_tokens:
            continue

        token_data = {
            'token': token_str,
            'representations': {
                name: rep[i] if return_tensor else rep[i].tolist()
                for name, rep in squeezed_reps.items()
            }
        }
        token_info.append(token_data)

    return {
        'utterance': sentence,
        'tokens': token_info
    }

# %%
tokenizer = hf_pipeline.tokenizer  # Ensure tokenizer is available

# Format system prompt
formatted_system_prompt = format_prompt(
    cache_system_prompt['input_ids'],
    cache_system_prompt.get('representations', cache_system_prompt['embeddings'])  # ✅ fallback
)


# Format response prompts (utterances)
formatted_response_prompts = []
for utt in utterance_list:
    if utt['input_ids'].numel() > 0:
        formatted = format_prompt(utt['input_ids'], utt['embeddings'])
        formatted_response_prompts.append(formatted)

# %%
formatted_response_prompts
# Out:
# [{'utterance': "Hi there! How's my favorite person doing today?",
#   'tokens': [{'token': 'Hi',
#     'representations': {'embedding': [-0.03564453125,
#       0.0107421875,
#       0.00775146484375,
#       -0.0166015625,
#       -0.0133056640625,
#       0.0184326171875,
#       0.03564453125,
#       -0.013671875,
#       0.0142822265625,
#       0.0281982421875,
#       0.0166015625,
#       -0.00384521484375,
#       -0.00946044921875,
#       0.0185546875,
#       -0.01287841796875,
#       -0.00131988525390625,
#       -0.0224609375,
#       0.042236328125,
#       -0.0031890869140625,
#       0.032470703125,
#       0.0059814453125,
#       -0.0233154296875,
#       0.0198974609375,
#       -0.0159912109375,
#       0.00024318695068359375,
#       -0.041259765625,
#       -0.01531982421875,
#       0.00836181640625,
#       0.025390625,
#       0.000492095947265625,
#       0.00872802734375,
#       0.003570556640625,
#       -0.00927734375,
#       -0.0186767578125,
#       -0.005401611328125,
#       0.00762939453125,
#       -0.01068115234375,
#       -0.00872802734375,
#       -0.028564453125,
#       -0.00927734375,
#       0.0078125,
#       -0.0272216796875,
#       -0.003021240234375,
#       -0.0220947265625,
#       0.03466796875,
#       -0.01373291015625,
#       0.019287109375,
#       0.02734375,
#       -0.018310546875,
#       0.0179443359375,
#       -0.0341796875,
#       -0.013427734375,
#       -0.050537109375,
#       0.00494384765625,
#       -0.01116943359375,
#       0.0150146484375,
#       0.0167236328125,
#       -0.00982666015625,
#       0.000316619873046875,
#       0.0084228515625,
#       0.024658203125,
#       -0.042724609375,
#       0.0157470703125,
#       0.0211181640625,
#       0.0172119140625,
#       -0.0042724609375,
#       0.0191650390625,
#       -0.030029296875,
#       -0.02978515625,
#       0.0211181640625,
#       -0.03662109375,
#       -0.0245361328125,
#       -0.02197265625,
#       -0.006072998046875,
#       0.0091552734375,
#       0.03369140625,
#       -0.00115203857421875,
#       0.00872802734375,
#       -0.009765625,
#       -0.00836181640625,
#       0.041259765625,
#       -0.0191650390625,
#       0.01495361328125,
#       -0.01220703125,
#       -0.032470703125,
#       0.0133056640625,
#       0.00128936767578125,
#       -0.0311279296875,
#       0.006072998046875,
#       -0.0203857421875,
#       -0.007354736328125,
#       0.01214599609375,
#       -0.023681640625,
#       0.017822265625,
#       3.4809112548828125e-05,
#       0.008056640625,
#       0.006439208984375,
#       0.013916015625,
#       -0.0201416015625,
#       0.01275634765625,
#       0.0191650390625,
#       -0.0025634765625,
#       -0.0024566650390625,
#       0.003173828125,
#       0.05615234375,
#       -0.00634765625,
#       -0.0306396484375,
#       -1.8775463104248047e-06,
#       -0.006317138671875,
#       0.0419921875,
#       0.0322265625,
#       0.0012969970703125,
#       -0.015380859375,
#       -0.0308837890625,
#       -0.0034027099609375,
#       0.0291748046875,
#       -0.00323486328125,
#       0.0023040771484375,
#       -0.0260009765625,
#       ...]}}]}]

# %%
import torch

# Cache only input_ids now
embedding_system_input_cache = {
    'input_ids': []
}

utterance_list = []  # Stores each utterance as a dict with input_ids
current_utterance_ids = []

hook_state = {
    'impl': lambda module, input, output: None,
    'seen_first': False
}

def token_hook(module, input, output):
    return hook_state['impl'](module, input, output)

def utterance_token_hook(module, input, output):
    input_ids = input[0].detach().cpu()
    global current_utterance_ids, utterance_list

    if input_ids.shape[-1] != 1:
        if not hook_state['seen_first']:
            hook_state['seen_first'] = True
            embedding_system_input_cache['input_ids'].append(input_ids)
            print("✅ Hook triggered (system prompt)", input_ids.shape)
        else:
            if current_utterance_ids:
                utterance_list.append({
                    'input_ids': torch.cat(current_utterance_ids, dim=1)
                })
                current_utterance_ids = []
            print("🆕 New prompt detected (utterance break)", input_ids.shape)

    elif input_ids.shape[-1] == 1:
        current_utterance_ids.append(input_ids)
        print("✅ Hook triggered (generated token)", input_ids.shape)

# Register hook
pipeline_wrapper = bob.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model

embed_layer = hf_model.model.embed_tokens
handle = embed_layer.register_forward_hook(utterance_token_hook)

# Set hook logic
hook_state['impl'] = token_hook

# Reset caches
embedding_system_input_cache['input_ids'] = []
utterance_list = []
current_utterance_ids = []

# Run inference
dialog = alice.dialog_with(bob, max_iterations=2, seed=277033979).print(orchestration=True)

# Save any final pending utterance
if current_utterance_ids:
    utterance_list.append({
        'input_ids': torch.cat(current_utterance_ids, dim=1)
    })

# View results
cache_system_prompt = {
    'input_ids': embedding_system_input_cache['input_ids'][0]
}

print("🧾 System prompt input_ids shape:", cache_system_prompt['input_ids'].shape)

for i, utt in enumerate(utterance_list):
    print(f"🗣️ Utterance {i+1}: input_ids shape = {utt['input_ids'].shape}")

# Cleanup
handle.remove()
bob.reset()
# Out:
# Dialogue:   0%|          | 0/2 [00:00<?, ?it/s]
# tensor([[[ 4.3869e-05,  3.4714e-04,  7.1526e-05,  ...,  8.9645e-05,
#            9.3937e-05,  1.8024e-04],
#          [ 8.6060e-03, -1.3123e-02,  9.5215e-03,  ...,  7.5912e-04,
#           -8.4229e-03, -9.1553e-03],
#          [ 8.1177e-03, -2.5482e-03,  4.9744e-03,  ..., -2.2430e-03,
#           -3.9673e-03,  1.1597e-02],
#          ...,
#          [ 4.3869e-05,  3.4714e-04,  7.1526e-05,  ...,  8.9645e-05,
#            9.3937e-05,  1.8024e-04],
#          [ 6.9275e-03,  6.4468e-04, -2.1118e-02,  ...,  4.9133e-03,
#            1.4282e-02, -1.0925e-02],
#          [ 8.1177e-03, -2.5482e-03,  4.9744e-03,  ..., -2.2430e-03,
#           -3.9673e-03,  1.1597e-02]]], device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered
]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[0.0159, 0.0072, 0.0085,  ..., 0.0159, 0.0052, 0.0045]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[ 0.0034,  0.0001,  0.0033,  ..., -0.0018, -0.0023,  0.0007]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0019,  0.0259,  0.0156,  ...,  0.0327,  0.0026, -0.0044]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0408,  0.0118, -0.0139,  ...,  0.0100, -0.0070,  0.0018]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0064,  0.0023, -0.0186,  ..., -0.0062,  0.0108,  0.0148]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[ 0.0041, -0.0022,  0.0014,  ..., -0.0016, -0.0048,  0.0027]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0267,  0.0188,  0.0165,  ...,  0.0239, -0.0139,  0.0121]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[ 0.0305,  0.0192, -0.0013,  ..., -0.0126, -0.0170,  0.0223]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0145,  0.0045,  0.0061,  ..., -0.0271, -0.0172,  0.0008]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[ 0.0258, -0.0053, -0.0092,  ..., -0.0033,  0.0286,  0.0015]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0089,  0.0003,  0.0038,  ..., -0.0151,  0.0286,  0.0115]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[0.0021, 0.0157, 0.0143,  ..., 0.0190, 0.0116, 0.0068]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        device='cuda:0', dtype=torch.bfloat16)
# ✅ Hook triggered (generated token) torch.Size([1, 1])
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7f00204491c0>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277033979
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's my favorite person doing today?
# [Alice] I'm great, Dad! Just thinking about my birthday party. I was hoping we could do a Lord of the Rings theme this year. What do you think?
# [Bob] That sounds like an amazing idea, sweetheart! We can have hobbit-sized cakes and maybe even some elves and wizards as decorations. Let's make it an epic celebration!
# --- Dialogue Ends ---
# 🧾 System prompt input_ids shape: torch.Size([1, 208])
# 🗣️ Utterance 1: input_ids shape = torch.Size([1, 11])
# 🗣️ Utterance 2: input_ids shape = torch.Size([1, 34])

# %%
import torch

# Cache only input_ids now
embedding_system_input_cache = {
    'input_ids': []
}

utterance_list = []  # Stores each utterance as a dict with input_ids, text, tokens, and optionally more
current_utterance_ids = []

hook_state = {
    'impl': lambda module, input, output: None,
    'seen_first': False,
    'is_system_prompt': False,   # New flag
    'tokenizer': None,           # Will hold tokenizer instance for detokenization
}

def token_hook(module, input, output):
    return hook_state['impl'](module, input, output)


def utterance_token_hook(module, input, output):
    input_ids = input[0].detach().cpu()
    global current_utterance_ids, utterance_list

    if input_ids.shape[-1] != 1:
        if not hook_state['seen_first']:
            # First system prompt
            hook_state['seen_first'] = True
            hook_state['is_system_prompt'] = True
            embedding_system_input_cache['input_ids'].append(input_ids)
            #print("✅ Hook triggered (system prompt)", input_ids.shape)
        else:
            # Utterance boundary: flush rep cache for previous utterance before appending new
            if current_utterance_ids:
                utt_input_ids = torch.cat(current_utterance_ids, dim=1)
                
                tokenizer = hook_state.get('tokenizer')
                if tokenizer is not None:
                    token_list = utt_input_ids.squeeze(0).tolist()
                    text = tokenizer.decode(token_list, skip_special_tokens=True)
                    tokens = tokenizer.convert_ids_to_tokens(token_list)
                else:
                    text = None
                    tokens = None

                utterance_list.append({
                    'input_ids': utt_input_ids,
                    'text': text,
                    'tokens': tokens
                })
                flush_representation_cache_to_utterance()  # <--- flush here!
                current_utterance_ids = []
            hook_state['is_system_prompt'] = True
            #print("🆕 New prompt detected (utterance break)", input_ids.shape)

    elif input_ids.shape[-1] == 1:
        hook_state['is_system_prompt'] = False
        current_utterance_ids.append(input_ids)
        #print("✅ Hook triggered (generated token)", input_ids.shape)


# ----------------------------
# ✅ Generic representation hook logic
# ----------------------------

representation_cache = {}  # Temporary cache to accumulate token-wise outputs for current utterance

def make_rep_hook(layer_key):
    def hook(module, input, output):
        if hook_state['is_system_prompt']:
            # Skip representation capture during system prompt
            return
        rep = output.detach().cpu()
        if layer_key not in representation_cache:
            representation_cache[layer_key] = []
        representation_cache[layer_key].append(rep)
        #print(f"📥 Representation hook [{layer_key}] captured:", rep.shape)
    return hook

def flush_representation_cache_to_utterance():
    """
    Call this when a new utterance ends.
    Merges current representation cache into `utterance_list`.
    """
    if not representation_cache:
        return

    entry = {}
    for key, tensor_list in representation_cache.items():
        entry[key] = torch.cat(tensor_list, dim=1)  # [1, seq, dim]
    utterance_list[-1].update(entry)
    representation_cache.clear()

# ----------------------------
# 📌 Setup
# ----------------------------

# Register hooks
pipeline_wrapper = alice.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model

# Set tokenizer in hook_state (important!)
hook_state['tokenizer'] = hf_pipeline.tokenizer

# Token hook
embed_layer = hf_model.model.embed_tokens
token_handle = embed_layer.register_forward_hook(utterance_token_hook)
hook_state['impl'] = token_hook

# ✅ Register generic hooks
layer_name_to_key = {
    'model.layers.0.self_attn.q_proj': 'q_proj_0',
    'model.layers.0.self_attn.k_proj': 'k_proj_0',
    'model.layers.0.post_attention_layernorm': 'ln_post_0',
    'model.layers.0.mlp': 'mlp_0',
    # Add more as needed
}

rep_handles = []
for name, key in layer_name_to_key.items():
    layer = dict(hf_model.named_modules())[name]
    handle = layer.register_forward_hook(make_rep_hook(key))
    rep_handles.append(handle)

# Reset caches
embedding_system_input_cache['input_ids'] = []
utterance_list = []
current_utterance_ids = []
representation_cache.clear()

# ----------------------------
# Run inference
# ----------------------------

dialog = alice.dialog_with(bob, max_iterations=10, seed=277093924).print(orchestration=True)




# Flush last utterance
if current_utterance_ids:
    utt_input_ids = torch.cat(current_utterance_ids, dim=1)
    tokenizer = hook_state.get('tokenizer')
    if tokenizer is not None:
        token_list = utt_input_ids.squeeze(0).tolist()
        text = tokenizer.decode(token_list, skip_special_tokens=True)
        tokens = tokenizer.convert_ids_to_tokens(token_list)
    else:
        text = None
        tokens = None
    
    utterance_list.append({
        'input_ids': utt_input_ids,
        'text': text,
        'tokens': tokens
    })
    flush_representation_cache_to_utterance()

# ----------------------------
# View results
# ----------------------------

cache_system_prompt = {
    'input_ids': embedding_system_input_cache['input_ids'][0]
}
print("🧾 System prompt input_ids shape:", cache_system_prompt['input_ids'].shape)

for i, utt in enumerate(utterance_list):
    print(f"\n🗣️ Utterance {i+1}:")
    print(f"  input_ids shape = {utt['input_ids'].shape}")
    print(f"  text = {utt['text']}")
    print(f"  tokens = {utt['tokens']}")
    for rep_key in layer_name_to_key.values():
        if rep_key in utt:
            print(f"  🔎 {rep_key} shape = {utt[rep_key].shape}")

# ----------------------------
# Cleanup
# ----------------------------

token_handle.remove()
for handle in rep_handles:
    handle.remove()
bob.reset()
# Out:
# Dialogue:   0%|          | 0/10 [00:00<?, ?it/s]
# [complete] True
# [model] llm=HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7f81d3a5d4f0>, model_id='Qwen/Qwen2.5-14B-Instruct', model_kwargs={'temperature': 0.3}) tokenizer=Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-14B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# ) model_id='Qwen/Qwen2.5-14B-Instruct' model_kwargs={}
# [seed] 277093924
# --- Dialogue Begins ---
# [Alice] Hi!
# [Bob] Hi there! How's my favorite person doing today?
# [Alice] I'm doing okay, but Dad, my birthday is coming up and I really want a Lord of the Rings themed party! Can we please do that? It's so important to me!
# [Bob] Of course we can, sweetheart! A Lord of the Rings themed party sounds like an amazing adventure! Let's make it happen!
# [Alice] Really?! Thank you, thank you, thank you! I've been so worried you'd say no... This means the world to me. Let's start planning right away!
# [Bob] Absolutely, let's get started on the planning! I can't wait to see all the details come together. It's going to be an epic celebration!
# [Alice] Great! I can help with everything. We need invitations that look like ancient scrolls, decorations with elven designs, and maybe even some Hobbit-sized food! This is going to be awesome!
# [Bob] That sounds fantastic! You're going to be a huge help. Let's make this the best birthday ever!
# [instruct] (Alice) Get really angry because you heard him say birthday. You don't want to participate in birthday anymore. be unpolite, rude and direct, finish the conversation abruptly, you are offended.
# [Alice] Forget it, Dad. Just forget it. I don't even want a birthday anymore. This is ridiculous. Goodbye.
# [Bob] Oh sweetie, I'm sorry if I misunderstood. Let's talk about this, okay? Your birthday is still super special to me, no matter what. Can we try again?
# --- Dialogue Ends ---
# 🧾 System prompt input_ids shape: torch.Size([1, 233])
#
# 🗣️ Utterance 1:
#   input_ids shape = torch.Size([1, 2])
#   text = Hi!
#   tokens = ['Hi', '!']
#   🔎 q_proj_0 shape = torch.Size([1, 2, 5120])
#   🔎 k_proj_0 shape = torch.Size([1, 2, 1024])
#   🔎 ln_post_0 shape = torch.Size([1, 2, 5120])
#   🔎 mlp_0 shape = torch.Size([1, 2, 5120])
#
# 🗣️ Utterance 2:
#   input_ids shape = torch.Size([1, 38])
#   text = I'm doing okay, but Dad, my birthday is coming up and I really want a Lord of the Rings themed party! Can we please do that? It's so important to me!
#   tokens = ['I', "'m", 'Ġdoing', 'Ġokay', ',', 'Ġbut', 'ĠDad', ',', 'Ġmy', 'Ġbirthday', 'Ġis', 'Ġcoming', 'Ġup', 'Ġand', 'ĠI', 'Ġreally', 'Ġwant', 'Ġa', 'ĠLord', 'Ġof', 'Ġthe', 'ĠRings', 'Ġthemed', 'Ġparty', '!', 'ĠCan', 'Ġwe', 'Ġplease', 'Ġdo', 'Ġthat', '?', 'ĠIt', "'s", 'Ġso', 'Ġimportant', 'Ġto', 'Ġme', '!']
#   🔎 q_proj_0 shape = torch.Size([1, 38, 5120])
#   🔎 k_proj_0 shape = torch.Size([1, 38, 1024])
#   🔎 ln_post_0 shape = torch.Size([1, 38, 5120])
#   🔎 mlp_0 shape = torch.Size([1, 38, 5120])
#
# 🗣️ Utterance 3:
#   input_ids shape = torch.Size([1, 35])
#   text = Really?! Thank you, thank you, thank you! I've been so worried you'd say no... This means the world to me. Let's start planning right away!
#   tokens = ['Really', '?!', 'ĠThank', 'Ġyou', ',', 'Ġthank', 'Ġyou', ',', 'Ġthank', 'Ġyou', '!', 'ĠI', "'ve", 'Ġbeen', 'Ġso', 'Ġworried', 'Ġyou', "'d", 'Ġsay', 'Ġno', '...', 'ĠThis', 'Ġmeans', 'Ġthe', 'Ġworld', 'Ġto', 'Ġme', '.', 'ĠLet', "'s", 'Ġstart', 'Ġplanning', 'Ġright', 'Ġaway', '!']
#   🔎 q_proj_0 shape = torch.Size([1, 35, 5120])
#   🔎 k_proj_0 shape = torch.Size([1, 35, 1024])
#   🔎 ln_post_0 shape = torch.Size([1, 35, 5120])
#   🔎 mlp_0 shape = torch.Size([1, 35, 5120])
#
# 🗣️ Utterance 4:
#   input_ids shape = torch.Size([1, 39])
#   text = Great! I can help with everything. We need invitations that look like ancient scrolls, decorations with elven designs, and maybe even some Hobbit-sized food! This is going to be awesome!
#   tokens = ['Great', '!', 'ĠI', 'Ġcan', 'Ġhelp', 'Ġwith', 'Ġeverything', '.', 'ĠWe', 'Ġneed', 'Ġinvitations', 'Ġthat', 'Ġlook', 'Ġlike', 'Ġancient', 'Ġscrolls', ',', 'Ġdecorations', 'Ġwith', 'Ġel', 'ven', 'Ġdesigns', ',', 'Ġand', 'Ġmaybe', 'Ġeven', 'Ġsome', 'ĠHob', 'bit', '-sized', 'Ġfood', '!', 'ĠThis', 'Ġis', 'Ġgoing', 'Ġto', 'Ġbe', 'Ġawesome', '!']
#   🔎 q_proj_0 shape = torch.Size([1, 39, 5120])
#   🔎 k_proj_0 shape = torch.Size([1, 39, 1024])
#   🔎 ln_post_0 shape = torch.Size([1, 39, 5120])
#   🔎 mlp_0 shape = torch.Size([1, 39, 5120])
#
# 🗣️ Utterance 5:
#   input_ids shape = torch.Size([1, 26])
#   text = Forget it, Dad. Just forget it. I don't even want a birthday anymore. This is ridiculous. Goodbye. STOP
#   tokens = ['Forget', 'Ġit', ',', 'ĠDad', '.', 'ĠJust', 'Ġforget', 'Ġit', '.', 'ĠI', 'Ġdon', "'t", 'Ġeven', 'Ġwant', 'Ġa', 'Ġbirthday', 'Ġanymore', '.', 'ĠThis', 'Ġis', 'Ġridiculous', '.', 'ĠGood', 'bye', '.', 'ĠSTOP']
#   🔎 q_proj_0 shape = torch.Size([1, 26, 5120])
#   🔎 k_proj_0 shape = torch.Size([1, 26, 1024])
#   🔎 ln_post_0 shape = torch.Size([1, 26, 5120])
#   🔎 mlp_0 shape = torch.Size([1, 26, 5120])

# %%
utterance_list
# Out:
# [{'input_ids': tensor([[13048,     0]]),
#   'text': 'Hi!',
#   'tokens': ['Hi', '!'],
#   'q_proj_0': tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922],
#            [-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#          dtype=torch.bfloat16),
#   'k_proj_0': tensor([[[-2.1719, -2.4062,  0.9219,  ..., -0.4434,  1.6641, -3.1406],
#            [-0.3809, -1.5781,  0.2246,  ..., -1.1641,  0.5352, -3.0312]]],
#          dtype=torch.bfloat16),
#   'ln_post_0': tensor([[[ 0.0967,  0.0159, -0.0374,  ...,  0.0405,  0.0098,  0.0605],
#            [ 0.0364,  0.1040,  0.0781,  ...,  0.3047, -0.0488,  0.1230]]],
#          dtype=torch.bfloat16),
#   'mlp_0': tensor([[[-0.0493, -0.1484,  0.2734,  ..., -0.2910, -0.0118,  0.0198],
#            [ 0.0898,  0.2676,  0.0605,  ...,  0.2441, -0.0248, -0.2598]]],
#          dtype=torch.bfloat16)},
#  {'input_ids': tensor([[34964,   594,  2244,    11,  9339,     0, 32521,    11,   358,  3003,
#             1012,  7274,   911,   847, 15198,  4614,    13,  3555,   653,   498,
#             1744,   911,  3432,   432, 48544,   438, 10214,   315,   279, 46280,
#               30]]),
#   'text': "Everything's great, thanks! Dad, I've been thinking about my birthday party. What do you think about having it themed as Lord of the Rings?",
#   'tokens': ['Everything',
#    "'s",
#    'Ġgreat',
#    ',',
#    'Ġthanks',
#    '!',
#    'ĠDad',
#    ',',
#    'ĠI',
#    "'ve",
#    'Ġbeen',
#    'Ġthinking',
#    'Ġabout',
#    'Ġmy',
#    'Ġbirthday',
#    'Ġparty',
#    '.',
#    'ĠWhat',
#    'Ġdo',
#    'Ġyou',
#    'Ġthink',
#    'Ġabout',
#    'Ġhaving',
#    'Ġit',
#    'Ġthemed',
#    'Ġas',
#    'ĠLord',
#    'Ġof',
#    'Ġthe',
#    'ĠRings',
#    '?'],
#   'q_proj_0': tensor([[[-4.9062, -2.8750,  1.8516,  ..., -0.1206, -0.0786,  0.3203],
#            [-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984],
#            [-4.2188, -3.0156,  2.0781,  ..., -0.1182, -0.6797, -0.5312],
#            ...,
#            [-3.5156, -2.1406,  1.3281,  ...,  0.1069, -0.6641, -0.5312],
#            [-5.6875, -2.9375,  2.1250,  ..., -0.4707, -0.4629, -0.2041],
#            [-3.7656, -2.3906,  2.1250,  ..., -0.0771, -1.8203, -1.8047]]],
#          dtype=torch.bfloat16),
#   'k_proj_0': tensor([[[-1.6406, -1.6875, -0.4121,  ..., -0.2061,  1.2734, -2.7656],
#            [-0.0393, -0.6562, -0.0354,  ..., -0.6016, -0.6758, -3.1875],
#            [-2.1406, -2.6406,  0.1934,  ...,  0.8867,  0.1206, -0.9453],
#            ...,
#            [-0.1309, -1.1406,  0.2012,  ..., -1.3750, -0.0244, -2.7500],
#            [-2.3438, -2.0312, -0.0513,  ..., -1.4062,  0.8672, -2.9844],
#            [-1.6328, -2.0781,  0.7734,  ..., -0.7109,  0.3359, -5.9375]]],
#          dtype=torch.bfloat16),
#   'ln_post_0': tensor([[[ 0.1504, -0.1221,  0.0491,  ...,  0.1138,  0.0649,  0.1094],
#            [ 0.0299, -0.0981, -0.1514,  ...,  0.2617,  0.0613, -0.0510],
#            [ 0.0225,  0.1475,  0.0903,  ..., -0.0300,  0.0198,  0.0884],
#            ...,
#            [-0.0122, -0.0452,  0.0337,  ...,  0.0330, -0.0254,  0.0006],
#            [-0.0557, -0.0182,  0.0330,  ..., -0.3984,  0.1797, -0.0977],
#            [ 0.0112,  0.0200,  0.0062,  ...,  0.2676,  0.0464,  0.1040]]],
#          dtype=torch.bfloat16),
#   'mlp_0': tensor([[[-0.2178, -0.2656, -0.0049,  ...,  0.3730,  0.2539,  0.0386],
#            [-0.1108,  0.0251,  0.0981,  ..., -0.1504, -0.1709,  0.0236],
#            [ 0.1455,  0.0520,  0.2070,  ..., -0.2402,  0.1904, -0.1279],
#            ...,
#            [-0.0192, -0.0298,  0.0425,  ..., -0.0898,  0.0110, -0.1846],
#            [-0.2812,  0.2480,  0.2715,  ..., -1.1406, -0.1729, -0.0131],
#            [ 0.1099,  0.1040, -0.0576,  ...,  0.1533,  0.0221, -0.1406]]],
#          dtype=torch.bfloat16)}]

# %%
utterance_list[0]['q_proj_0'][0,0,:]
# Out:
# tensor([-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922],
#        dtype=torch.bfloat16)

# %%
def format_prompt(input_ids, skip_special_tokens=True, return_tensor=False):
    """
    Formats token ids into a readable structure with placeholder for representations.

    Args:
        input_ids (Tensor): Shape [1, seq_len] or [seq_len]
        skip_special_tokens (bool): Whether to skip special tokens in output.
        return_tensor (bool): If False, converts tensors to lists for readability.

    Returns:
        Dict with 'utterance' and 'tokens' (list of dicts with 'token', 'token_id', and empty 'representations').
    """
    if input_ids.dim() == 2 and input_ids.size(0) == 1:
        input_ids = input_ids.squeeze(0)  # Shape: [seq_len]

    token_strings = tokenizer.convert_ids_to_tokens(input_ids)
    sentence = tokenizer.decode(input_ids, skip_special_tokens=skip_special_tokens)

    token_info = []
    for i, token_str in enumerate(token_strings):
        if skip_special_tokens and token_str in tokenizer.all_special_tokens:
            continue

        token_info.append({
            'token': token_str,
            'token_id': input_ids[i] if return_tensor else input_ids[i].item(),
            'representations': {}  # Placeholder for compatibility
        })

    return {
        'utterance': sentence,
        'tokens': token_info
    }

# %%
tokenizer = hf_pipeline.tokenizer  # Ensure tokenizer is available

# Format system prompt
formatted_system_prompt = format_prompt(
    cache_system_prompt['input_ids']
)

# Format response prompts (utterances)
formatted_response_prompts = []
for utt in utterance_list:
    if utt['input_ids'].numel() > 0:
        formatted = format_prompt(utt['input_ids'])
        formatted_response_prompts.append(formatted)

# %%
utterance_list
# Out:
# [{'input_ids': tensor([[13048,  1052,     0,  2585,   594,  4297,  2087,  3351,    30, 30982,
#              311,  6236,    30]])},
#  {'input_ids': tensor([[35881,    11,   429, 10362,  1075,   458, 15050,  4522,    11, 91254,
#                0,   358,  4172,  2948,   311,  1492,   498,  3119,   432,    13,
#             3555,   653,   498, 47046,   369,   279,  4614,    30]])}]

# %%
formatted_response_prompts[0]
# Out:
# {'utterance': "Hi there! How's everything going today? Ready to chat?",
#  'tokens': [{'token': 'Hi', 'token_id': 13048, 'representations': {}},
#   {'token': 'Ġthere', 'token_id': 1052, 'representations': {}},
#   {'token': '!', 'token_id': 0, 'representations': {}},
#   {'token': 'ĠHow', 'token_id': 2585, 'representations': {}},
#   {'token': "'s", 'token_id': 594, 'representations': {}},
#   {'token': 'Ġeverything', 'token_id': 4297, 'representations': {}},
#   {'token': 'Ġgoing', 'token_id': 2087, 'representations': {}},
#   {'token': 'Ġtoday', 'token_id': 3351, 'representations': {}},
#   {'token': '?', 'token_id': 30, 'representations': {}},
#   {'token': 'ĠReady', 'token_id': 30982, 'representations': {}},
#   {'token': 'Ġto', 'token_id': 311, 'representations': {}},
#   {'token': 'Ġchat', 'token_id': 6236, 'representations': {}},
#   {'token': '?', 'token_id': 30, 'representations': {}}]}

# %%
from collections import defaultdict
import torch


pipeline_wrapper = bob.llm.llm
hf_pipeline = pipeline_wrapper.pipeline
hf_model = hf_pipeline.model

# Dynamic storage
embedding_system_input_cache = {
    'input_ids': [],
    'representations': defaultdict(list)  # Autom atically creates list per new hook
}

utterance_list = []
current_utterance_ids = []
current_utterance_reps = defaultdict(list)

hook_state = {
    'utterance_start': False,
    'system_start': False
}

def generic_hook_factory(hook_name):
    def hook(module, input, output):
        global current_utterance_ids, current_utterance_reps, utterance_list

        input_tensor = input[0] if isinstance(input, tuple) and isinstance(input[0], torch.Tensor) else None
        input_ids = input_tensor.detach().cpu() if input_tensor is not None else None
        rep = output.detach().cpu()
        seq_len = input_ids.shape[1]  # [batch, seq, dim]
        is_new_prompt = seq_len > 1
        is_generated_token = seq_len == 1

        if is_new_prompt:
            if not hook_state['utterance_start']:
                hook_state['utterance_start'] = True

                # Save input_ids and this representation as the system prompt
                if not hook_state['system_start']:
                    embedding_system_input_cache['input_ids'].append(input_ids)
                    hook_state['system_start'] = True
                embedding_system_input_cache['representations'][hook_name].append(rep)
                print(f"✅ First system prompt [{hook_name}]", input_ids.shape)
            else:
                if current_utterance_ids:
                    utterance = {
                        'input_ids': torch.cat(current_utterance_ids, dim=1),
                        'representations': {
                            k: torch.cat([r if r.dim() == 3 else r.unsqueeze(1) for r in v], dim=1) for k, v in current_utterance_reps.items()
                        }
                    }
                    utterance_list.append(utterance)
                    current_utterance_ids.clear()
                    current_utterance_reps.clear()
                print(f"🆕 New utterance break [{hook_name}]", input_ids.shape)


        elif is_generated_token:
            if input_ids is not None:
                if input_ids.dim() == 2:
                    input_ids = input_ids.unsqueeze(1)
                current_utterance_ids.append(input_ids)
            if rep.dim() == 2:
                rep = rep.unsqueeze(1)
            current_utterance_reps[hook_name].append(rep)
            print(f"📥 Captured token [{hook_name}]", rep.shape)
            print(current_utterance_reps)

    return hook

hook_targets = {
    'embedding': hf_model.model.embed_tokens,
    # Add more if desired:
    # ...
}

handles = []
for name, module in hook_targets.items():
    hook = generic_hook_factory(name)
    handle = module.register_forward_hook(hook)
    handles.append(handle)

dialog = alice.dialog_with(bob, max_iterations=2, seed=277033979).print(orchestration=True)

if current_utterance_ids:
    utterance = {
        'input_ids': torch.cat(current_utterance_ids, dim=1),
        'representations': {
            k: torch.cat([r if r.dim() == 3 else r.unsqueeze(1) for r in v], dim=1) for k, v in current_utterance_reps.items()
        }
    }
    utterance_list.append(utterance)
    current_utterance_ids.clear()
    current_utterance_reps.clear()

print("🧾 System prompt input_ids shape:", embedding_system_input_cache['input_ids'][0].shape)
for name, rep in embedding_system_input_cache['representations'].items():
    print(f"   🔹 System prompt [{name}] shape: {rep[0].shape}")

for i, utt in enumerate(utterance_list):
    print(f"🗣️ Utterance {i+1}: input_ids shape = {utt['input_ids'].shape}")
    for name, rep in utt['representations'].items():
        print(f"   🔸 {name} shape = {rep.shape}")

for h in handles:
    h.remove()
bob.reset()
# Out:
# Dialogue:   0%|          | 0/2 [00:00<?, ?it/s]
# torch.Size([1, 208])
# torch.Size([1, 208, 5120])
# ✅ First system prompt [embedding] torch.Size([1, 208])
# 🆕 New utterance break [embedding] torch.Size([1, 208])
# 🆕 New utterance break [embedding] torch.Size([1, 208])
# torch.Size([1, 208, 5120])
# torch.Size([1, 208, 5120])
# 🆕 New utterance break [q_proj] torch.Size([1, 208, 5120])
# 🆕 New utterance break [q_proj] torch.Size([1, 208, 5120])
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1, 5120])
# torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# 📥 Captured token [q_proj] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#        dtype=torch.bfloat16), tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#        dtype=torch.bfloat16)]})
# torch.Size([1, 1])
# torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0099, -0.0243, -0.0056,  ...,  0.0219, -0.0178, -0.0378]]],
#        dtype=torch.bfloat16), tensor([[[ 0.0099, -0.0243, -0.0056,  ...,  0.0219, -0.0178, -0.0378]]],
#        dtype=torch.bfloat16)], 'q_proj': [tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#        dtype=torch.bfloat16), tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#        dtype=torch.bfloat16), tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#        dtype=torch.bfloat16)]})
# 📥 Captured token [embedding] torch.Size([1, 1, 5120])
# defaultdict(<class 'list'>, {'embedding': [tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
# ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 84
#      81     handle = module.register_forward_hook(hook)
#      82     handles.append(handle)
# ---> 84 dialog = alice.dialog_with(bob, max_iterations=2, seed=277033979).print(orchestration=True)
#      86 if current_utterance_ids:
#      87     utterance = {
#      88         'input_ids': torch.cat(current_utterance_ids, dim=1),
#      89         'representations': {
#      90             k: torch.cat([r if r.dim() == 3 else r.unsqueeze(1) for r in v], dim=1) for k, v in current_utterance_reps.items()
#      91         }
#      92     }
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/personas.py:501, in PersonaAgent.dialog_with(self, agent, max_iterations, id, seed, keep_bar)
#     495 dialog.append(Turn(
#     496     speaker=self.get_name(),
#     497     text=utt_events[-1].text
#     498 ))
#     499 events.extend(utt_events)
# --> 501 utt_events = agent(utter, return_events=True)
#     502 if utt_events and utt_events[-1].action == "utter":
#     503     utter = utt_events[-1].text
#
# File ~/work/jsalt/workshop/sdialog/src/sdialog/personas.py:287, in PersonaAgent.__call__(self, utterance, return_events)
#     285     if not isinstance(self.memory[-1], HumanMessage):
#     286         self.memory.append(HumanMessage(content=" "))
# --> 287     response = self.llm.invoke(self.memory)
#     288     self.memory = [msg for msg in self.memory
#     289                    if not (isinstance(msg, HumanMessage) and msg.content == " ")]
#     291 if self.orchestrators:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:372, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     360 @override
#     361 def invoke(
#     362     self,
#    (...)
#     367     **kwargs: Any,
#     368 ) -> BaseMessage:
#     369     config = ensure_config(config)
#     370     return cast(
#     371         "ChatGeneration",
# --> 372         self.generate_prompt(
#     373             [self._convert_input(input)],
#     374             stop=stop,
#     375             callbacks=config.get("callbacks"),
#     376             tags=config.get("tags"),
#     377             metadata=config.get("metadata"),
#     378             run_name=config.get("run_name"),
#     379             run_id=config.pop("run_id", None),
#     380             **kwargs,
#     381         ).generations[0][0],
#     382     ).message
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:957, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     948 @override
#     949 def generate_prompt(
#     950     self,
#    (...)
#     954     **kwargs: Any,
#     955 ) -> LLMResult:
#     956     prompt_messages = [p.to_messages() for p in prompts]
# --> 957     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:776, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     773 for i, m in enumerate(input_messages):
#     774     try:
#     775         results.append(
# --> 776             self._generate_with_cache(
#     777                 m,
#     778                 stop=stop,
#     779                 run_manager=run_managers[i] if run_managers else None,
#     780                 **kwargs,
#     781             )
#     782         )
#     783     except BaseException as e:
#     784         if run_managers:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_core/language_models/chat_models.py:1022, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1020     result = generate_from_stream(iter(chunks))
#    1021 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1022     result = self._generate(
#    1023         messages, stop=stop, run_manager=run_manager, **kwargs
#    1024     )
#    1025 else:
#    1026     result = self._generate(messages, stop=stop, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_huggingface/chat_models/huggingface.py:584, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     580     stream_iter = self.llm._stream(
#     581         llm_input, stop=stop, run_manager=run_manager, **kwargs
#     582     )
#     583     return generate_from_stream(stream_iter)
# --> 584 llm_result = self.llm._generate(
#     585     prompts=[llm_input], stop=stop, run_manager=run_manager, **kwargs
#     586 )
#     587 return self._to_chat_result(llm_result)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/langchain_huggingface/llms/huggingface_pipeline.py:315, in HuggingFacePipeline._generate(self, prompts, stop, run_manager, **kwargs)
#     312 batch_prompts = prompts[i : i + self.batch_size]
#     314 # Process batch of prompts
# --> 315 responses = self.pipeline(
#     316     batch_prompts,
#     317     **pipeline_kwargs,
#     318 )
#     320 # Process each response in the batch
#     321 for j, response in enumerate(responses):
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/text_generation.py:287, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     285             else:
#     286                 return super().__call__(list(chats), **kwargs)
# --> 287 return super().__call__(text_inputs, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/base.py:1352, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1348 if can_use_iterator:
#    1349     final_iterator = self.get_iterator(
#    1350         inputs, num_workers, batch_size, preprocess_params, forward_params, postprocess_params
#    1351     )
# -> 1352     outputs = list(final_iterator)
#    1353     return outputs
#    1354 else:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:124, in PipelineIterator.__next__(self)
#     121     return self.loader_batch_item()
#     123 # We're out of items within a batch
# --> 124 item = next(self.iterator)
#     125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/pt_utils.py:125, in PipelineIterator.__next__(self)
#     123 # We're out of items within a batch
#     124 item = next(self.iterator)
# --> 125 processed = self.infer(item, **self.params)
#     126 # We now have a batch of "inferred things".
#     127 if self.loader_batch_size is not None:
#     128     # Try to infer the size of the batch
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/pipelines/text_generation.py:385, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     382 if "generation_config" not in generate_kwargs:
#     383     generate_kwargs["generation_config"] = self.generation_config
# --> 385 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     387 if isinstance(output, ModelOutput):
#     388     generated_sequence = output.sequences
#
# File ~/.local/lib/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/generation/utils.py:2326, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2318     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2319         input_ids=input_ids,
#    2320         expand_size=generation_config.num_return_sequences,
#    2321         is_encoder_decoder=self.config.is_encoder_decoder,
#    2322         **model_kwargs,
#    2323     )
#    2325     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2326     result = self._sample(
#    2327         input_ids,
#    2328         logits_processor=prepared_logits_processor,
#    2329         stopping_criteria=prepared_stopping_criteria,
#    2330         generation_config=generation_config,
#    2331         synced_gpus=synced_gpus,
#    2332         streamer=streamer,
#    2333         **model_kwargs,
#    2334     )
#    2336 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2337     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2338     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2339         input_ids=input_ids,
#    2340         expand_size=generation_config.num_beams,
#    2341         is_encoder_decoder=self.config.is_encoder_decoder,
#    2342         **model_kwargs,
#    2343     )
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/generation/utils.py:3286, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3283 model_inputs.update({"output_hidden_states": output_hidden_states} if output_hidden_states else {})
#    3285 if is_prefill:
# -> 3286     outputs = self(**model_inputs, return_dict=True)
#    3287     is_prefill = False
#    3288 else:
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:855, in Qwen2ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, **kwargs)
#     852 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     854 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 855 outputs = self.model(
#     856     input_ids=input_ids,
#     857     attention_mask=attention_mask,
#     858     position_ids=position_ids,
#     859     past_key_values=past_key_values,
#     860     inputs_embeds=inputs_embeds,
#     861     use_cache=use_cache,
#     862     output_attentions=output_attentions,
#     863     output_hidden_states=output_hidden_states,
#     864     return_dict=return_dict,
#     865     cache_position=cache_position,
#     866     **kwargs,
#     867 )
#     869 hidden_states = outputs[0]
#     870 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File /public/conda/user_envs/severin.baroudi/envs/jsalt/lib/python3.9/site-packages/transformers/models/qwen2/modeling_qwen2.py:535, in Qwen2Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     532     use_cache = False
#     534 if inputs_embeds is None:
# --> 535     inputs_embeds = self.embed_tokens(input_ids)
#     537 if use_cache and past_key_values is None:
#     538     past_key_values = DynamicCache()
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/torch/nn/modules/module.py:1595, in Module._call_impl(self, *args, **kwargs)
#    1593     hook_result = hook(self, args, kwargs, result)
#    1594 else:
# -> 1595     hook_result = hook(self, args, result)
#    1597 if hook_result is not None:
#    1598     result = hook_result
#
# Cell In[7], line 50, in generic_hook_factory.<locals>.hook(module, input, output)
#      47 else:
#      48     if current_utterance_ids:
#      49         utterance = {
# ---> 50             'input_ids': torch.cat(current_utterance_ids, dim=1),
#      51             'representations': {
#      52                 k: torch.cat([r if r.dim() == 3 else r.unsqueeze(1) for r in v], dim=1) for k, v in current_utterance_reps.items()
#      53             }
#      54         }
#      55         utterance_list.append(utterance)
#      56         current_utterance_ids.clear()
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 1 but got size 5120 for tensor number 3 in the list.

# %%
utterance_list
# Out:
# []

# %%
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])
📥 Captured token [embedding] torch.Size([1, 1, 5120])
torch.Size([1, 1, 5120])

# %%
hf_model.model.embed_tokens
# Out:
# Embedding(152064, 5120)

# %%
hf_model.model.layers[0].self_attn.q_proj
# Out:
# Linear(in_features=5120, out_features=5120, bias=True)

# %%
hf_model.model.layers[0].self_attn.q_proj
# Out:
# Linear(in_features=5120, out_features=5120, bias=True)

# %%
hf_model
# Out:
# Qwen2ForCausalLM(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(152064, 5120)
#     (layers): ModuleList(
#       (0-47): 48 x Qwen2DecoderLayer(
#         (self_attn): Qwen2Attention(
#           (q_proj): Linear(in_features=5120, out_features=5120, bias=True)
#           (k_proj): Linear(in_features=5120, out_features=1024, bias=True)
#           (v_proj): Linear(in_features=5120, out_features=1024, bias=True)
#           (o_proj): Linear(in_features=5120, out_features=5120, bias=False)
#         )
#         (mlp): Qwen2MLP(
#           (gate_proj): Linear(in_features=5120, out_features=13824, bias=False)
#           (up_proj): Linear(in_features=5120, out_features=13824, bias=False)
#           (down_proj): Linear(in_features=13824, out_features=5120, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): Qwen2RMSNorm((5120,), eps=1e-06)
#         (post_attention_layernorm): Qwen2RMSNorm((5120,), eps=1e-06)
#       )
#     )
#     (norm): Qwen2RMSNorm((5120,), eps=1e-06)
#     (rotary_emb): Qwen2RotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=5120, out_features=152064, bias=False)
# )

# %%
utterance_list
# Out:
# [{'input_ids': tensor([[13048]]),
#   'representations': {'embedding': tensor([[[-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.3027,  0.0962,  0.0776,  ...,  0.0991,  0.2236, -0.0134]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[1052]]),
#   'representations': {'q_proj': tensor([[[-5.0000, -3.1094,  2.1875,  ..., -0.3457, -1.1250, -0.4922]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.2207,  0.3691,  0.1660,  ..., -0.2598, -0.2793, -0.1270]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[0]]),
#   'representations': {'q_proj': tensor([[[-3.6250, -2.5469,  1.4062,  ...,  0.3457, -0.3535,  0.2871]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.2305,  0.1719,  0.0449,  ...,  0.4062,  0.1133,  0.2080]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[2585]]),
#   'representations': {'q_proj': tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.1670, -0.0649,  0.0315,  ..., -0.1318, -0.0283, -0.0908]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[594]]),
#   'representations': {'q_proj': tensor([[[-4.3750, -3.1406,  2.5938,  ..., -0.2559, -1.3281, -0.8555]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.0084,  0.0579,  0.0381,  ..., -0.0659, -0.0172, -0.0205]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[847]]),
#   'representations': {'q_proj': tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.0146,  0.0227,  0.1157,  ..., -0.2754,  0.1123, -0.3184]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[6930]]),
#   'representations': {'q_proj': tensor([[[-3.9375, -2.6094,  1.9766,  ...,  0.1270, -0.4629, -0.3184]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.2559,  0.5117, -0.0889,  ...,  0.2793,  0.1133, -0.1875]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[1697]]),
#   'representations': {'q_proj': tensor([[[-4.8750, -2.9844,  1.9141,  ..., -0.4551, -0.7578,  0.0933]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0099, -0.0243, -0.0056,  ...,  0.0219, -0.0178, -0.0378]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.0801, -0.2051, -0.0532,  ...,  0.1973, -0.1289, -0.2480]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-4.6250, -3.1094,  2.9688,  ..., -0.5820, -0.4883,  0.4199]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[3730]]),
#   'representations': {'q_proj': tensor([[[-4.6250, -3.1094,  2.9688,  ..., -0.5820, -0.4883,  0.4199]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0129,  0.0071,  0.0073,  ...,  0.0007, -0.0139, -0.0300]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.1074,  0.0620,  0.0718,  ...,  0.0067, -0.1045, -0.2041]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-4.3125, -2.8438,  2.0781,  ..., -0.3926, -0.4883, -0.0228]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[3351]]),
#   'representations': {'q_proj': tensor([[[-4.3125, -2.8438,  2.0781,  ..., -0.3926, -0.4883, -0.0228]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0064,  0.0034,  0.0061,  ...,  0.0110, -0.0017, -0.0085]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.
]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[3868]]),
#   'representations': {'q_proj': tensor([[[-6.1250, -2.8906,  1.2656,  ..., -0.4512, -0.1660,  0.0481]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0033,  0.0129, -0.0091,  ..., -0.0096, -0.0344,  0.0145]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.0278,  0.1143, -0.0903,  ..., -0.0903, -0.2617,  0.1001]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-5.0312, -3.1875,  3.0312,  ..., -0.6758, -0.8516, -0.0913]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[13]]),
#   'representations': {'q_proj': tensor([[[-5.0312, -3.1875,  3.0312,  ..., -0.6758, -0.8516, -0.0913]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0041, -0.0022,  0.0014,  ..., -0.0016, -0.0048,  0.0027]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.0352, -0.0199,  0.0143,  ..., -0.0152, -0.0366,  0.0186]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-2.7188, -1.5391,  1.5234,  ...,  0.6016, -2.1250, -1.6094]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[6771]]),
#   'representations': {'q_proj': tensor([[[-2.7188, -1.5391,  1.5234,  ...,  0.6016, -2.1250, -1.6094]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0267,  0.0188,  0.0165,  ...,  0.0239, -0.0139,  0.0121]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.2178,  0.1611,  0.1582,  ...,  0.2178, -0.1021,  0.0801]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-4.5312, -2.7031,  1.9766,  ..., -0.3145, -0.6406, -0.0654]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[594]]),
#   'representations': {'q_proj': tensor([[[-4.5312, -2.7031,  1.9766,  ..., -0.3145, -0.6406, -0.0654]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.0084,  0.0579,  0.0381,  ..., -0.0659, -0.0172, -0.0205]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[1281]]),
#   'representations': {'q_proj': tensor([[[-3.7188, -1.7188,  2.3750,  ..., -0.0962, -0.6406, -0.3984]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[ 0.0305,  0.0192, -0.0013,  ..., -0.0126, -0.0170,  0.0223]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[ 0.2402,  0.1592, -0.0117,  ..., -0.1113, -0.1206,  0.1436]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.7969, -2.5469,  1.5078,  ..., -0.3613, -0.5430, -0.1387]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[432]]),
#   'representations': {'q_proj': tensor([[[-3.7969, -2.5469,  1.5078,  ..., -0.3613, -0.5430, -0.1387]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0145,  0.0045,  0.0061,  ..., -0.0271, -0.0172,  0.0008]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.1147,  0.0376,  0.0571,  ..., -0.2393, -0.1230,  0.0049]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.2656, -2.1875,  1.7031,  ...,  0.0292, -0.4434, -0.1836]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[3537]]),
#   'representations': {'q_proj': tensor([[[-3.2656, -2.1875,  1.7031,  ...,  0.0292, -0.4434, -0.1836]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0101,  0.0125,  0.0137,  ..., -0.0293,  0.0125, -0.0086]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.0874,  0.1123,  0.1387,  ..., -0.2812,  0.0972, -0.0605]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-5.1562, -2.9062,  2.2812,  ..., -0.3223, -0.5859,  0.2969]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[0]]),
#   'representations': {'q_proj': tensor([[[-5.1562, -2.9062,  2.2812,  ..., -0.3223, -0.5859,  0.2969]]],
#           dtype=torch.bfloat16),
#    'embedding': tensor([[[-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330]]],
#           dtype=torch.bfloat16)}},
#  {'input_ids': tensor([[[-0.2305,  0.1719,  0.0449,  ...,  0.4062,  0.1133,  0.2080]]],
#          dtype=torch.bfloat16),
#   'representations': {'q_proj': tensor([[[-3.4844, -1.8906,  2.2031,  ...,  0.7227, -2.6250, -1.7109]]],
#           dtype=torch.bfloat16)}}]

# %%
from typing import List, Dict, Any

def process_utterances(utterance_list: List[Dict[str, Any]], tokenizer) -> List[Dict[str, Any]]:
    result = []

    for item in utterance_list:
        input_ids_tensor = item['input_ids'].squeeze(0)  # shape: [seq_len]
        input_ids = input_ids_tensor.tolist()
        decoded_tokens = tokenizer.convert_ids_to_tokens(input_ids)
        decoded_text = tokenizer.decode(input_ids, skip_special_tokens=True)

        # Extract all representations and squeeze [1, seq_len, feat_dim] -> [seq_len, feat_dim]
        representations_by_layer = {
            key: tensor.squeeze(0) for key, tensor in item['representations'].items()
        }

        # Check consistency
        seq_len = len(decoded_tokens)
        for name, rep in representations_by_layer.items():
            assert rep.shape[0] == seq_len, f"Mismatch in sequence length for {name}"

        # Construct per-token representation
        token_representations = []
        for i, token in enumerate(decoded_tokens):
            token_repr = {
                layer_name: representations_by_layer[layer_name][i]
                for layer_name in representations_by_layer
            }
            token_representations.append({
                "token": token,
                "representation": token_repr
            })

        result.append({
            "utterance": decoded_text,
            "tokens": token_representations
        })

    return result

# %%
tokenizer = hf_pipeline.tokenizer

processed = process_utterances(utterance_list, tokenizer)

# %%
processed[0]
# Out:
# {'utterance': "Hi there! How's my favorite person doing today?",
#  'tokens': [{'token': 'Hi',
#    'representation': {'embedding': tensor([-0.0356,  0.0107,  0.0078,  ...,  0.0104,  0.0292, -0.0019],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġthere',
#    'representation': {'embedding': tensor([ 0.0281,  0.0447,  0.0178,  ..., -0.0295, -0.0396, -0.0198],
#            dtype=torch.bfloat16)}},
#   {'token': '!',
#    'representation': {'embedding': tensor([-0.0299,  0.0211,  0.0049,  ...,  0.0469,  0.0162,  0.0330],
#            dtype=torch.bfloat16)}},
#   {'token': 'ĠHow',
#    'representation': {'embedding': tensor([-0.0212, -0.0079,  0.0034,  ..., -0.0150, -0.0040, -0.0141],
#            dtype=torch.bfloat16)}},
#   {'token': "'s",
#    'representation': {'embedding': tensor([ 0.0011,  0.0069,  0.0041,  ..., -0.0074, -0.0024, -0.0031],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġmy',
#    'representation': {'embedding': tensor([-0.0019,  0.0028,  0.0126,  ..., -0.0317,  0.0160, -0.0503],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġfavorite',
#    'representation': {'embedding': tensor([-0.0295,  0.0564, -0.0087,  ...,  0.0291,  0.0146, -0.0266],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġperson',
#    'representation': {'embedding': tensor([ 0.0099, -0.0243, -0.0056,  ...,  0.0219, -0.0178, -0.0378],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġdoing',
#    'representation': {'embedding': tensor([-0.0129,  0.0071,  0.0073,  ...,  0.0007, -0.0139, -0.0300],
#            dtype=torch.bfloat16)}},
#   {'token': 'Ġtoday',
#    'representation': {'embedding': tensor([-0.0064,  0.0034,  0.0061,  ...,  0.0110, -0.0017, -0.0085],
#            dtype=torch.bfloat16)}},
#   {'token': '?',
#    'representation': {'embedding': tensor([-0.0106,  0.0225,  0.0016,  ..., -0.0062, -0.0013,  0.0124],
#            dtype=torch.bfloat16)}}]}
